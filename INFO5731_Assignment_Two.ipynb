# %% [markdown]
# <a href="https://colab.research.google.com/github/SangeethaKaveti/sangeetha_INFO5731_Spring2023/blob/main/INFO5731_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon.
#
# (2) Collect the top 10000 User Reviews of a film recently in 2023 or 2022 (you can choose any film) from IMDB.
#
# (3) Collect all the reviews of the top 1000 most popular software from [G2](https://www.g2.com/) or [Capterra](https://www.capterra.com/)
#
# (4) Collect the abstracts of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from [Semantic Scholar](https://www.semanticscholar.org).
#
# (5) Collect all the information of the 904 narrators in the [Densho Digital Repository](https://ddr.densho.org/narrators/).
#
# (6) Collect the top 10000 tweets by using a hashtag (you can use any hashtag) from Twitter.

# %%
# Write your code here

import requests  
from bs4 import BeautifulSoup as bs 
import re

# %%
iphone_reviews=[]
for i in range(1,1000):
  ip=[]  
  url="https://www.amazon.com/Apple-iPhone-11-64GB-Unlocked/product-reviews/B07ZPKF8RG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"+str(i)
  response = requests.get(url)
  soup = bs(response.content,"html.parser") 
  reviews = soup.find_all("div",attrs={"class","a-row a-spacing-small review-data"})  
  for i in range(len(reviews)):
    ip.append((reviews[i].text).replace('\n',''))
    iphone_reviews=iphone_reviews+ip

# %%
import pandas as pd
reviews= pd.DataFrame(iphone_reviews,columns=['reviews'])
reviews
# Out:
#                                                reviews
# 0    The 'minor visual blemishes' for me were that ...
# 1    The 'minor visual blemishes' for me were that ...
# 2    Phone looked new to me. I've been a landline u...
# 3    The 'minor visual blemishes' for me were that ...
# 4    Phone looked new to me. I've been a landline u...
# ..                                                 ...
# 215  I was little hesitant to a refurbished phone. ...
# 216  It has taken me some time getting use to this ...
# 217  We had to purchase our daughter a new phone la...
# 218  I was very hesitant on making this purchase af...
# 219  Shipping was quick and excellent shape describ...
#
# [220 rows x 1 columns]

# %%
reviews.to_csv('data.csv', index=False)

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write your code here
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#                                                reviews
# 0    The 'minor visual blemishes' for me were that ...
# 1    The 'minor visual blemishes' for me were that ...
# 2    Phone looked new to me. I've been a landline u...
# 3    The 'minor visual blemishes' for me were that ...
# 4    Phone looked new to me. I've been a landline u...
# ..                                                 ...
# 215  I was little hesitant to a refurbished phone. ...
# 216  It has taken me some time getting use to this ...
# 217  We had to purchase our daughter a new phone la...
# 218  I was very hesitant on making this purchase af...
# 219  Shipping was quick and excellent shape describ...
#
# [220 rows x 1 columns]

# %%
df['Number of Characters'] = df['reviews'].str.len()
df
# Out:
#                                                reviews  Number of Characters
# 0    The 'minor visual blemishes' for me were that ...                  1170
# 1    The 'minor visual blemishes' for me were that ...                  1170
# 2    Phone looked new to me. I've been a landline u...                   546
# 3    The 'minor visual blemishes' for me were that ...                  1170
# 4    Phone looked new to me. I've been a landline u...                   546
# ..                                                 ...                   ...
# 215  I was little hesitant to a refurbished phone. ...                   336
# 216  It has taken me some time getting use to this ...                   329
# 217  We had to purchase our daughter a new phone la...                   622
# 218  I was very hesitant on making this purchase af...                   258
# 219  Shipping was quick and excellent shape describ...                   584
#
# [220 rows x 2 columns]

# %%
df['Numbers of numerics'] = df['reviews'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
df
# Out:
#                                                reviews  Number of Characters  \
# 0    The 'minor visual blemishes' for me were that ...                  1170
# 1    The 'minor visual blemishes' for me were that ...                  1170
# 2    Phone looked new to me. I've been a landline u...                   546
# 3    The 'minor visual blemishes' for me were that ...                  1170
# 4    Phone looked new to me. I've been a landline u...                   546
# ..                                                 ...                   ...
# 215  I was little hesitant to a refurbished phone. ...                   336
# 216  It has taken me some time getting use to this ...                   329
# 217  We had to purchase our daughter a new phone la...                   622
# 218  I was very hesitant on making this purchase af...                   258
# 219  Shipping was quick and excellent shape describ...                   584
#
#      Numbers of numerics
# 0                      0
# 1                      0
# 2                      1
# 3                      0
# 4                      1
# ..                   ...
# 215                    1
# 216                    2
# 217                    1
# 218                    0
# 219                    4
#
# [220 rows x 3 columns]

# %%
df['digits removal'] = df['reviews'].apply(lambda x: ''.join([i for i in x if not i.isdigit()]))
df
# Out:
#                                                reviews  Number of Characters  \
# 0    The 'minor visual blemishes' for me were that ...                  1170
# 1    The 'minor visual blemishes' for me were that ...                  1170
# 2    Phone looked new to me. I've been a landline u...                   546
# 3    The 'minor visual blemishes' for me were that ...                  1170
# 4    Phone looked new to me. I've been a landline u...                   546
# ..                                                 ...                   ...
# 215  I was little hesitant to a refurbished phone. ...                   336
# 216  It has taken me some time getting use to this ...                   329
# 217  We had to purchase our daughter a new phone la...                   622
# 218  I was very hesitant on making this purchase af...                   258
# 219  Shipping was quick and excellent shape describ...                   584
#
#      Numbers of numerics                                     digits removal
# 0                      0  The 'minor visual blemishes' for me were that ...
# 1                      0  The 'minor visual blemishes' for me were that ...
# 2                      1  Phone looked new to me. I've been a landline u...
# 3                      0  The 'minor visual blemishes' for me were that ...
# 4                      1  Phone looked new to me. I've been a landline u...
# ..                   ...                                                ...
# 215                    1  I was little hesitant to a refurbished phone. ...
# 216                    2  It has taken me some time getting use to this ...
# 217                    1  We had to purchase our daughter a new phone la...
# 218                    0  I was very hesitant on making this purchase af...
# 219                    4  Shipping was quick and excellent shape describ...
#
# [220 rows x 4 columns]

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['Stopwords Removal'] = df['reviews'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df
# Out:
#                                                reviews  Number of Characters  \
# 0    The 'minor visual blemishes' for me were that ...                  1170
# 1    The 'minor visual blemishes' for me were that ...                  1170
# 2    Phone looked new to me. I've been a landline u...                   546
# 3    The 'minor visual blemishes' for me were that ...                  1170
# 4    Phone looked new to me. I've been a landline u...                   546
# ..                                                 ...                   ...
# 215  I was little hesitant to a refurbished phone. ...                   336
# 216  It has taken me some time getting use to this ...                   329
# 217  We had to purchase our daughter a new phone la...                   622
# 218  I was very hesitant on making this purchase af...                   258
# 219  Shipping was quick and excellent shape describ...                   584
#
#      Numbers of numerics                                     digits removal  \
# 0                      0  The 'minor visual blemishes' for me were that ...
# 1                      0  The 'minor visual blemishes' for me were that ...
# 2                      1  Phone looked new to me. I've been a landline u...
# 3                      0  The 'minor visual blemishes' for me were that ...
# 4                      1  Phone looked new to me. I've been a landline u...
# ..                   ...                                                ...
# 215                    1  I was little hesitant to a refurbished phone. ...
# 216                    2  It has taken me some time getting use to this ...
# 217                    1  We had to purchase our daughter a new phone la...
# 218                    0  I was very hesitant on making this purchase af...
# 219                    4  Shipping was quick and excellent shape describ...
#
#                                      Stopwords Removal
# 0    The 'minor visual blemishes' edges case bit sc...
# 1    The 'minor visual blemishes' edges case bit sc...
# 2    Phone looked new me. I've landline users since...
# 3    The 'minor visual blemishes' edges case bit sc...
# 4    Phone looked new me. I've landline users since...
# ..                                                 ...
# 215  I little hesitant refurbished phone. This firs...
# 216  It taken time getting use phone11; I SE. The r...
# 217  We purchase daughter new phone last minute see...
# 218  I hesitant making purchase reading reviews. Ho...
# 219  Shipping quick excellent shape described perfe...
#
# [220 rows x 5 columns]

# %%
df['Lower Case'] = df['reviews'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df
# Out:
#                                                reviews  Number of Characters  \
# 0    The 'minor visual blemishes' for me were that ...                  1170
# 1    The 'minor visual blemishes' for me were that ...                  1170
# 2    Phone looked new to me. I've been a landline u...                   546
# 3    The 'minor visual blemishes' for me were that ...                  1170
# 4    Phone looked new to me. I've been a landline u...                   546
# ..                                                 ...                   ...
# 215  I was little hesitant to a refurbished phone. ...                   336
# 216  It has taken me some time getting use to this ...                   329
# 217  We had to purchase our daughter a new phone la...                   622
# 218  I was very hesitant on making this purchase af...                   258
# 219  Shipping was quick and excellent shape describ...                   584
#
#      Numbers of numerics                                     digits removal  \
# 0                      0  The 'minor visual blemishes' for me were that ...
# 1                      0  The 'minor visual blemishes' for me were that ...
# 2                      1  Phone looked new to me. I've been a landline u...
# 3                      0  The 'minor visual blemishes' for me were that ...
# 4                      1  Phone looked new to me. I've been a landline u...
# ..                   ...                                                ...
# 215                    1  I was little hesitant to a refurbished phone. ...
# 216                    2  It has taken me some time getting use to this ...
# 217                    1  We had to purchase our daughter a new phone la...
# 218                    0  I was very hesitant on making this purchase af...
# 219                    4  Shipping was quick and excellent shape describ...
#
#                                      Stopwords Removal  \
# 0    The 'minor visual blemishes' edges case bit sc...
# 1    The 'minor visual blemishes' edges case bit sc...
# 2    Phone looked new me. I've landline users since...
# 3    The 'minor visual blemishes' edges case bit sc...
# 4    Phone looked new me. I've landline users since...
# ..                                                 ...
# 215  I little hesitant refurbished phone. This firs...
# 216  It taken time getting use phone11; I SE. The r...
# 217  We purchase daughter new phone last minute see...
# 218  I hesitant making purchase reading reviews. Ho...
# 219  Shipping quick excellent shape described perfe...
#
#                                             Lower Case
# 0    the 'minor visual blemishes' for me were that ...
# 1    the 'minor visual blemishes' for me were that ...
# 2    phone looked new to me. i've been a landline u...
# 3    the 'minor visual blemishes' for me were that ...
# 4    phone looked new to me. i've been a landline u...
# ..                                                 ...
# 215  i was little hesitant to a refurbished phone. ...
# 216  it has taken me some time getting use to this ...
# 217  we had to purchase our daughter a new phone la...
# 218  i was very hesitant on making this purchase af...
# 219  shipping was quick and excellent shape describ...
#
# [220 rows x 6 columns]

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['Stemming'] = df['Lower Case'].apply(lambda x: " ".join([st.stem(word) for word in x]))
df
# Out:
#                                                reviews  Number of Characters  \
# 0    The 'minor visual blemishes' for me were that ...                  1170
# 1    The 'minor visual blemishes' for me were that ...                  1170
# 2    Phone looked new to me. I've been a landline u...                   546
# 3    The 'minor visual blemishes' for me were that ...                  1170
# 4    Phone looked new to me. I've been a landline u...                   546
# ..                                                 ...                   ...
# 215  I was little hesitant to a refurbished phone. ...                   336
# 216  It has taken me some time getting use to this ...                   329
# 217  We had to purchase our daughter a new phone la...                   622
# 218  I was very hesitant on making this purchase af...                   258
# 219  Shipping was quick and excellent shape describ...                   584
#
#      Numbers of numerics                                     digits removal  \
# 0                      0  The 'minor visual blemishes' for me were that ...
# 1                      0  The 'minor visual blemishes' for me were that ...
# 2                      1  Phone looked new to me. I've been a landline u...
# 3                      0  The 'minor visual blemishes' for me were that ...
# 4                      1  Phone looked new to me. I've been a landline u...
# ..                   ...                                                ...
# 215                    1  I was little hesitant to a refurbished phone. ...
# 216                    2  It has taken me some time getting use to this ...
# 217                    1  We had to purchase our daughter a new phone la...
# 218                    0  I was very hesitant on making this purchase af...
# 219                    4  Shipping was quick and excellent shape describ...
#
#                                      Stopwords Removal  \
# 0    The 'minor visual blemishes' edges case bit sc...
# 1    The 'minor visual blemishes' edges case bit sc...
# 2    Phone looked new me. I've landline users since...
# 3    The 'minor visual blemishes' edges case bit sc...
# 4    Phone looked new me. I've landline users since...
# ..                                                 ...
# 215  I little hesitant refurbished phone. This firs...
# 216  It taken time getting use phone11; I SE. The r...
# 217  We purchase daughter new phone last minute see...
# 218  I hesitant making purchase reading reviews. Ho...
# 219  Shipping quick excellent shape described perfe...
#
#                                             Lower Case  \
# 0    the 'minor visual blemishes' for me were that ...
# 1    the 'minor visual blemishes' for me were that ...
# 2    phone looked new to me. i've been a landline u...
# 3    the 'minor visual blemishes' for me were that ...
# 4    phone looked new to me. i've been a landline u...
# ..                                                 ...
# 215  i was little hesitant to a refurbished phone. ...
# 216  it has taken me some time getting use to this ...
# 217  we had to purchase our daughter a new phone la...
# 218  i was very hesitant on making this purchase af...
# 219  shipping was quick and excellent shape describ...
#
#                                               Stemming
# 0    t h e   ' m i n o r   v i s u a l   b l e m i ...
# 1    t h e   ' m i n o r   v i s u a l   b l e m i ...
# 2    p h o n e   l o o k e d   n e w   t o   m e . ...
# 3    t h e   ' m i n o r   v i s u a l   b l e m i ...
# 4    p h o n e   l o o k e d   n e w   t o   m e . ...
# ..                                                 ...
# 215  i   w a s   l i t t l e   h e s i t a n t   t ...
# 216  i t   h a s   t a k e n   m e   s o m e   t i ...
# 217  w e   h a d   t o   p u r c h a s e   o u r   ...
# 218  i   w a s   v e r y   h e s i t a n t   o n   ...
# 219  s h i p p i n g   w a s   q u i c k   a n d   ...
#
# [220 rows x 7 columns]

# %%
df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')
df
# Out:
# <ipython-input-35-7c8ac01b3304>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')
#                                                reviews  Number of Characters  \
# 0    The 'minor visual blemishes' for me were that ...                  1170
# 1    The 'minor visual blemishes' for me were that ...                  1170
# 2    Phone looked new to me. I've been a landline u...                   546
# 3    The 'minor visual blemishes' for me were that ...                  1170
# 4    Phone looked new to me. I've been a landline u...                   546
# ..                                                 ...                   ...
# 215  I was little hesitant to a refurbished phone. ...                   336
# 216  It has taken me some time getting use to this ...                   329
# 217  We had to purchase our daughter a new phone la...                   622
# 218  I was very hesitant on making this purchase af...                   258
# 219  Shipping was quick and excellent shape describ...                   584
#
#      Numbers of numerics                                     digits removal  \
# 0                      0  The 'minor visual blemishes' for me were that ...
# 1                      0  The 'minor visual blemishes' for me were that ...
# 2                      1  Phone looked new to me. I've been a landline u...
# 3                      0  The 'minor visual blemishes' for me were that ...
# 4                      1  Phone looked new to me. I've been a landline u...
# ..                   ...                                                ...
# 215                    1  I was little hesitant to a refurbished phone. ...
# 216                    2  It has taken me some time getting use to this ...
# 217                    1  We had to purchase our daughter a new phone la...
# 218                    0  I was very hesitant on making this purchase af...
# 219                    4  Shipping was quick and excellent shape describ...
#
#                                      Stopwords Removal  \
# 0    The 'minor visual blemishes' edges case bit sc...
# 1    The 'minor visual blemishes' edges case bit sc...
# 2    Phone looked new me. I've landline users since...
# 3    The 'minor visual blemishes' edges case bit sc...
# 4    Phone looked new me. I've landline users since...
# ..                                                 ...
# 215  I little hesitant refurbished phone. This firs...
# 216  It taken time getting use phone11; I SE. The r...
# 217  We purchase daughter new phone last minute see...
# 218  I hesitant making purchase reading reviews. Ho...
# 219  Shipping quick excellent shape described perfe...
#
#                                             Lower Case  \
# 0    the 'minor visual blemishes' for me were that ...
# 1    the 'minor visual blemishes' for me were that ...
# 2    phone looked new to me. i've been a landline u...
# 3    the 'minor visual blemishes' for me were that ...
# 4    phone looked new to me. i've been a landline u...
# ..                                                 ...
# 215  i was little hesitant to a refurbished phone. ...
# 216  it has taken me some time getting use to this ...
# 217  we had to purchase our daughter a new phone la...
# 218  i was very hesitant on making this purchase af...
# 219  shipping was quick and excellent shape describ...
#
#                                               Stemming  \
# 0    t h e   ' m i n o r   v i s u a l   b l e m i ...
# 1    t h e   ' m i n o r   v i s u a l   b l e m i ...
# 2    p h o n e   l o o k e d   n e w   t o   m e . ...
# 3    t h e   ' m i n o r   v i s u a l   b l e m i ...
# 4    p h o n e   l o o k e d   n e w   t o   m e . ...
# ..                                                 ...
# 215  i   w a s   l i t t l e   h e s i t a n t   t ...
# 216  i t   h a s   t a k e n   m e   s o m e   t i ...
# 217  w e   h a d   t o   p u r c h a s e   o u r   ...
# 218  i   w a s   v e r y   h e s i t a n t   o n   ...
# 219  s h i p p i n g   w a s   q u i c k   a n d   ...
#
#                                 Removal of Punctuation
# 0    the minor visual blemishes for me were that th...
# 1    the minor visual blemishes for me were that th...
# 2    phone looked new to me ive been a landline use...
# 3    the minor visual blemishes for me were that th...
# 4    phone looked new to me ive been a landline use...
# ..                                                 ...
# 215  i was little hesitant to a refurbished phone t...
# 216  it has taken me some time getting use to this ...
# 217  we had to purchase our daughter a new phone la...
# 218  i was very hesitant on making this purchase af...
# 219  shipping was quick and excellent shape describ...
#
# [220 rows x 8 columns]

# %%
from textblob import Word
import nltk
nltk.download('wordnet')
df['Lemmatization'] = df['Removal of Punctuation'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                reviews  Number of Characters  \
# 0    The 'minor visual blemishes' for me were that ...                  1170
# 1    The 'minor visual blemishes' for me were that ...                  1170
# 2    Phone looked new to me. I've been a landline u...                   546
# 3    The 'minor visual blemishes' for me were that ...                  1170
# 4    Phone looked new to me. I've been a landline u...                   546
# ..                                                 ...                   ...
# 215  I was little hesitant to a refurbished phone. ...                   336
# 216  It has taken me some time getting use to this ...                   329
# 217  We had to purchase our daughter a new phone la...                   622
# 218  I was very hesitant on making this purchase af...                   258
# 219  Shipping was quick and excellent shape describ...                   584
#
#      Numbers of numerics                                     digits removal  \
# 0                      0  The 'minor visual blemishes' for me were that ...
# 1                      0  The 'minor visual blemishes' for me were that ...
# 2                      1  Phone looked new to me. I've been a landline u...
# 3                      0  The 'minor visual blemishes' for me were that ...
# 4                      1  Phone looked new to me. I've been a landline u...
# ..                   ...                                                ...
# 215                    1  I was little hesitant to a refurbished phone. ...
# 216                    2  It has taken me some time getting use to this ...
# 217                    1  We had to purchase our daughter a new phone la...
# 218                    0  I was very hesitant on making this purchase af...
# 219                    4  Shipping was quick and excellent shape describ...
#
#                                      Stopwords Removal  \
# 0    The 'minor visual blemishes' edges case bit sc...
# 1    The 'minor visual blemishes' edges case bit sc...
# 2    Phone looked new me. I've landline users since...
# 3    The 'minor visual blemishes' edges case bit sc...
# 4    Phone looked new me. I've landline users since...
# ..                                                 ...
# 215  I little hesitant refurbished phone. This firs...
# 216  It taken time getting use phone11; I SE. The r...
# 217  We purchase daughter new phone last minute see...
# 218  I hesitant making purchase reading reviews. Ho...
# 219  Shipping quick excellent shape described perfe...
#
#                                             Lower Case  \
# 0    the 'minor visual blemishes' for me were that ...
# 1    the 'minor visual blemishes' for me were that ...
# 2    phone looked new to me. i've been a landline u...
# 3    the 'minor visual blemishes' for me were that ...
# 4    phone looked new to me. i've been a landline u...
# ..                                                 ...
# 215  i was little hesitant to a refurbished phone. ...
# 216  it has taken me some time getting use to this ...
# 217  we had to purchase our daughter a new phone la...
# 218  i was very hesitant on making this purchase af...
# 219  shipping was quick and excellent shape describ...
#
#                                               Stemming  \
# 0    t h e   ' m i n o r   v i s u a l   b l e m i ...
# 1    t h e   ' m i n o r   v i s u a l   b l e m i ...
# 2    p h o n e   l o o k e d   n e w   t o   m e . ...
# 3    t h e   ' m i n o r   v i s u a l   b l e m i ...
# 4    p h o n e   l o o k e d   n e w   t o   m e . ...
# ..                                                 ...
# 215  i   w a s   l i t t l e   h e s i t a n t   t ...
# 216  i t   h a s   t a k e n   m e   s o m e   t i ...
# 217  w e   h a d   t o   p u r c h a s e   o u r   ...
# 218  i   w a s   v e r y   h e s i t a n t   o n   ...
# 219  s h i p p i n g   w a s   q u i c k   a n d   ...
#
#                                 Removal of Punctuation  \
# 0    the minor visual blemishes for me were that th...
# 1    the minor visual blemishes for me were that th...
# 2    phone looked new to me ive been a landline use...
# 3    the minor visual blemishes for me were that th...
# 4    phone looked new to me ive been a landline use...
# ..                                                 ...
# 215  i was little hesitant to a refurbished phone t...
# 216  it has taken me some time getting use to this ...
# 217  we had to purchase our daughter a new phone la...
# 218  i was very hesitant on making this purchase af...
# 219  shipping was quick and excellent shape describ...
#
#                                          Lemmatization
# 0    the minor visual blemish for me were that the ...
# 1    the minor visual blemish for me were that the ...
# 2    phone looked new to me ive been a landline use...
# 3    the minor visual blemish for me were that the ...
# 4    phone looked new to me ive been a landline use...
# ..                                                 ...
# 215  i wa little hesitant to a refurbished phone th...
# 216  it ha taken me some time getting use to this p...
# 217  we had to purchase our daughter a new phone la...
# 218  i wa very hesitant on making this purchase aft...
# 219  shipping wa quick and excellent shape describe...
#
# [220 rows x 9 columns]

# %%
df.to_csv('cleaned_textdata.csv',index=False)

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Write your code here
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize
pos = []
for sentence in df['Lower Case']:
  text = word_tokenize(sentence)
  pos.append(nltk.pos_tag(text))
pos
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [[('the', 'DT'),
#   ("'minor", 'JJ'),
#   ('visual', 'JJ'),
#   ('blemishes', 'NNS'),
#   ("'", 'POS'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('were', 'VBD'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('case', 'NN'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('scuffed', 'JJ'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('if', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('just', 'RB'),
#   ('paint', 'JJ'),
#   ('peeling', 'NN'),
#   ('or', 'CC'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('refurbishing', 'VBG'),
#   ('company', 'NN'),
#   ('polished', 'VBD'),
#   ('it', 'PRP'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('rough', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('touch', 'NN'),
#   ('or', 'CC'),
#   ('anything', 'NN'),
#   (';', ':'),
#   ('just', 'RB'),
#   ('kinda', 'VB'),
#   ('spotted', 'VBN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('smooth', 'JJ'),
#   ('factory-new', 'JJ'),
#   ('finish.functionally', 'RB'),
#   (',', ','),
#   ('though', 'IN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('perfect', 'JJ'),
#   ('.', '.'),
#   ('they', 'PRP'),
#   ('replaced', 'VBD'),
#   (',', ','),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   (',', ','),
#   ('the', 'DT'),
#   ('display', 'NN'),
#   ('specifically', 'RB'),
#   ('?', '.'),
#   ('because', 'IN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('settings', 'NNS'),
#   ('menu', 'VBP'),
#   ('there', 'EX'),
#   ("'s", 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('warning', 'NN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ("'screen", 'NN'),
#   ('may', 'MD'),
#   ('not', 'RB'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('certified', 'JJ'),
#   ('part', 'NN'),
#   ("'", 'POS'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ('mean', 'NN'),
#   (',', ','),
#   ('okay', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('like', 'IN'),
#   ('i', 'JJ'),
#   ("'m", 'VBP'),
#   ('gon', 'VBG'),
#   ('na', 'TO'),
#   ('try', 'VB'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('a', 'DT'),
#   ('warranty', 'NN'),
#   ('replacement', 'NN'),
#   ('on', 'IN'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('right', 'RB'),
#   ('?', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('heard/read', 'VBN'),
#   ('things', 'NNS'),
#   ('about', 'IN'),
#   ('that', 'DT'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('camera', 'NN'),
#   ('(', '('),
#   ('s', 'NN'),
#   (')', ')'),
#   ('are', 'VBP'),
#   ('replaced', 'VBN'),
#   (',', ','),
#   ('faceid', 'JJ'),
#   ('and/or', 'NN'),
#   ('arkit', 'NN'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('function', 'VB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('for', 'IN'),
#   ('mine', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('seem', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('an', 'DT'),
#   ('issue', 'NN'),
#   ('-', ':'),
#   ('works', 'VBZ'),
#   ('just', 'RB'),
#   ('fine.i', 'VBN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('the', 'DT'),
#   ('standard/expected', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('say', 'VB'),
#   ('that', 'IN'),
#   ('i', 'NN'),
#   ('charged', 'VBD'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('overnight', 'VBD'),
#   ('to', 'TO'),
#   ('100', 'CD'),
#   ('%', 'NN'),
#   ('(', '('),
#   ('indicated', 'VBN'),
#   (')', ')'),
#   (',', ','),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('left', 'VBD'),
#   ('it', 'PRP'),
#   ('turned', 'VBD'),
#   ('on', 'IN'),
#   ('at', 'IN'),
#   ('home', 'NN'),
#   (',', ','),
#   ('connected', 'VBN'),
#   ('to', 'TO'),
#   ('wi-fi', 'NNS'),
#   ('in', 'IN'),
#   ('terms', 'NNS'),
#   ('of', 'IN'),
#   ('using', 'VBG'),
#   ('signal', 'JJ'),
#   ('in', 'IN'),
#   ('any', 'DT'),
#   ('way', 'NN'),
#   (';', ':'),
#   ('after', 'IN'),
#   ('about', 'IN'),
#   ('a', 'DT'),
#   ('10-hour', 'JJ'),
#   ('workday', 'NN'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('came', 'VBD'),
#   ('home', 'RB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('down', 'RB'),
#   ('to', 'TO'),
#   ('85', 'CD'),
#   ('%', 'NN'),
#   ('.', '.'),
#   ('again', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('sure', 'JJ'),
#   ('how', 'WRB'),
#   ('this', 'DT'),
#   ('measures', 'VBZ'),
#   ('up', 'RP'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('healthy', 'JJ'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('tell', 'VB'),
#   ('you', 'PRP'),
#   ('how', 'WRB'),
#   ('thirsty', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('under', 'IN'),
#   ('load', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('unit', 'NN'),
#   ('in', 'IN'),
#   ('standby', 'NN'),
#   ('that', 'IN'),
#   ('feels', 'NNS'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('normal', 'JJ'),
#   ('drain', 'NN'),
#   ('?', '.')],
#  [('the', 'DT'),
#   ("'minor", 'JJ'),
#   ('visual', 'JJ'),
#   ('blemishes', 'NNS'),
#   ("'", 'POS'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('were', 'VBD'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('case', 'NN'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('scuffed', 'JJ'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('if', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('just', 'RB'),
#   ('paint', 'JJ'),
#   ('peeling', 'NN'),
#   ('or', 'CC'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('refurbishing', 'VBG'),
#   ('company', 'NN'),
#   ('polished', 'VBD'),
#   ('it', 'PRP'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('rough', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('touch', 'NN'),
#   ('or', 'CC'),
#   ('anything', 'NN'),
#   (';', ':'),
#   ('just', 'RB'),
#   ('kinda', 'VB'),
#   ('spotted', 'VBN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('smooth', 'JJ'),
#   ('factory-new', 'JJ'),
#   ('finish.functionally', 'RB'),
#   (',', ','),
#   ('though', 'IN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('perfect', 'JJ'),
#   ('.', '.'),
#   ('they', 'PRP'),
#   ('replaced', 'VBD'),
#   (',', ','),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   (',', ','),
#   ('the', 'DT'),
#   ('display', 'NN'),
#   ('specifically', 'RB'),
#   ('?', '.'),
#   ('because', 'IN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('settings', 'NNS'),
#   ('menu', 'VBP'),
#   ('there', 'EX'),
#   ("'s", 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('warning', 'NN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ("'screen", 'NN'),
#   ('may', 'MD'),
#   ('not', 'RB'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('certified', 'JJ'),
#   ('part', 'NN'),
#   ("'", 'POS'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ('mean', 'NN'),
#   (',', ','),
#   ('okay', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('like', 'IN'),
#   ('i', 'JJ'),
#   ("'m", 'VBP'),
#   ('gon', 'VBG'),
#   ('na', 'TO'),
#   ('try', 'VB'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('a', 'DT'),
#   ('warranty', 'NN'),
#   ('replacement', 'NN'),
#   ('on', 'IN'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('right', 'RB'),
#   ('?', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('heard/read', 'VBN'),
#   ('things', 'NNS'),
#   ('about', 'IN'),
#   ('that', 'DT'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('camera', 'NN'),
#   ('(', '('),
#   ('s', 'NN'),
#   (')', ')'),
#   ('are', 'VBP'),
#   ('replaced', 'VBN'),
#   (',', ','),
#   ('faceid', 'JJ'),
#   ('and/or', 'NN'),
#   ('arkit', 'NN'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('function', 'VB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('for', 'IN'),
#   ('mine', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('seem', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('an', 'DT'),
#   ('issue', 'NN'),
#   ('-', ':'),
#   ('works', 'VBZ'),
#   ('just', 'RB'),
#   ('fine.i', 'VBN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('the', 'DT'),
#   ('standard/expected', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('say', 'VB'),
#   ('that', 'IN'),
#   ('i', 'NN'),
#   ('charged', 'VBD'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('overnight', 'VBD'),
#   ('to', 'TO'),
#   ('100', 'CD'),
#   ('%', 'NN'),
#   ('(', '('),
#   ('indicated', 'VBN'),
#   (')', ')'),
#   (',', ','),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('left', 'VBD'),
#   ('it', 'PRP'),
#   ('turned', 'VBD'),
#   ('on', 'IN'),
#   ('at', 'IN'),
#   ('home', 'NN'),
#   (',', ','),
#   ('connected', 'VBN'),
#   ('to', 'TO'),
#   ('wi-fi', 'NNS'),
#   ('in', 'IN'),
#   ('terms', 'NNS'),
#   ('of', 'IN'),
#   ('using', 'VBG'),
#   ('signal', 'JJ'),
#   ('in', 'IN'),
#   ('any', 'DT'),
#   ('way', 'NN'),
#   (';', ':'),
#   ('after', 'IN'),
#   ('about', 'IN'),
#   ('a', 'DT'),
#   ('10-hour', 'JJ'),
#   ('workday', 'NN'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('came', 'VBD'),
#   ('home', 'RB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('down', 'RB'),
#   ('to', 'TO'),
#   ('85', 'CD'),
#   ('%', 'NN'),
#   ('.', '.'),
#   ('again', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('sure', 'JJ'),
#   ('how', 'WRB'),
#   ('this', 'DT'),
#   ('measures', 'VBZ'),
#   ('up', 'RP'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('healthy', 'JJ'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('tell', 'VB'),
#   ('you', 'PRP'),
#   ('how', 'WRB'),
#   ('thirsty', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('under', 'IN'),
#   ('load', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('unit', 'NN'),
#   ('in', 'IN'),
#   ('standby', 'NN'),
#   ('that', 'IN'),
#   ('feels', 'NNS'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('normal', 'JJ'),
#   ('drain', 'NN'),
#   ('?', '.')],
#  [('phone', 'NN'),
#   ('looked', 'VBD'),
#   ('new', 'JJ'),
#   ('to', 'TO'),
#   ('me', 'PRP'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('been', 'VBN'),
#   ('a', 'DT'),
#   ('landline', 'NN'),
#   ('users', 'NNS'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('pup', 'NN'),
#   ('.', '.'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ("'s", 'POS'),
#   ('pretty', 'JJ'),
#   ('easy', 'JJ'),
#   ('to', 'TO'),
#   ('setup', 'VB'),
#   ('too', 'RB'),
#   ('.', '.'),
#   ('hardest', 'JJS'),
#   ('part', 'NN'),
#   ('(', '('),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   (')', ')'),
#   ('was', 'VBD'),
#   ('getting', 'VBG'),
#   ('the', 'DT'),
#   ('sim', 'NN'),
#   ('chip', 'NN'),
#   ('holder', 'NN'),
#   ('out', 'IN'),
#   ('.', '.'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('put', 'VB'),
#   ('the', 'DT'),
#   ('card', 'NN'),
#   ('in', 'IN'),
#   ('backwards', 'NNS'),
#   ('.', '.'),
#   ('so', 'RB'),
#   ('many', 'JJ'),
#   ('seem', 'VBP'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('this', 'DT'),
#   ('model', 'NN'),
#   ('of', 'IN'),
#   ('iphone', 'NN'),
#   ('.', '.'),
#   ('finding', 'VBG'),
#   ('my', 'PRP$'),
#   ('way', 'NN'),
#   ('around', 'IN'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('&', 'CC'),
#   ('setting', 'NN'),
#   ('things', 'NNS'),
#   ('up', 'RB'),
#   ('.', '.'),
#   ('carrier', 'NN'),
#   ('i', 'NN'),
#   ('signed', 'VBD'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('was', 'VBD'),
#   ('also', 'RB'),
#   ('super', 'JJ'),
#   ('helpful', 'NN'),
#   ('with', 'IN'),
#   ('setting', 'VBG'),
#   ('phone', 'NN'),
#   ('up', 'RB'),
#   ('&', 'CC'),
#   ('porting', 'VBG'),
#   ('my', 'PRP$'),
#   ('old', 'JJ'),
#   ('phone', 'NN'),
#   ('number', 'NN'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('give', 'VB'),
#   ('review', 'NN'),
#   ('stars', 'NNS'),
#   ('for', 'IN'),
#   ('everything', 'NN'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('no', 'DT'),
#   ('idea', 'NN'),
#   ('about', 'IN'),
#   ('battery', 'JJ'),
#   ('life', 'NN'),
#   ('or', 'CC'),
#   ('longevity', 'NN'),
#   (',', ','),
#   ('well', 'UH'),
#   ('its', 'PRP$'),
#   ('worked', 'JJ'),
#   ('fine', 'NN'),
#   ('for', 'IN'),
#   ('3', 'CD'),
#   ('days', 'NNS'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ("'minor", 'JJ'),
#   ('visual', 'JJ'),
#   ('blemishes', 'NNS'),
#   ("'", 'POS'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('were', 'VBD'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('case', 'NN'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('scuffed', 'JJ'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('if', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('just', 'RB'),
#   ('paint', 'JJ'),
#   ('peeling', 'NN'),
#   ('or', 'CC'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('refurbishing', 'VBG'),
#   ('company', 'NN'),
#   ('polished', 'VBD'),
#   ('it', 'PRP'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('rough', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('touch', 'NN'),
#   ('or', 'CC'),
#   ('anything', 'NN'),
#   (';', ':'),
#   ('just', 'RB'),
#   ('kinda', 'VB'),
#   ('spotted', 'VBN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('smooth', 'JJ'),
#   ('factory-new', 'JJ'),
#   ('finish.functionally', 'RB'),
#   (',', ','),
#   ('though', 'IN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('perfect', 'JJ'),
#   ('.', '.'),
#   ('they', 'PRP'),
#   ('replaced', 'VBD'),
#   (',', ','),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   (',', ','),
#   ('the', 'DT'),
#   ('display', 'NN'),
#   ('specifically', 'RB'),
#   ('?', '.'),
#   ('because', 'IN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('settings', 'NNS'),
#   ('menu', 'VBP'),
#   ('there', 'EX'),
#   ("'s", 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('warning', 'NN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ("'screen", 'NN'),
#   ('may', 'MD'),
#   ('not', 'RB'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('certified', 'JJ'),
#   ('part', 'NN'),
#   ("'", 'POS'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ('mean', 'NN'),
#   (',', ','),
#   ('okay', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('like', 'IN'),
#   ('i', 'JJ'),
#   ("'m", 'VBP'),
#   ('gon', 'VBG'),
#   ('na', 'TO'),
#   ('try', 'VB'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('a', 'DT'),
#   ('warranty', 'NN'),
#   ('replacement', 'NN'),
#   ('on', 'IN'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('right', 'RB'),
#   ('?', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('heard/read', 'VBN'),
#   ('things', 'NNS'),
#   ('about', 'IN'),
#   ('that', 'DT'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('camera', 'NN'),
#   ('(', '('),
#   ('s', 'NN'),
#   (')', ')'),
#   ('are', 'VBP'),
#   ('replaced', 'VBN'),
#   (',', ','),
#   ('faceid', 'JJ'),
#   ('and/or', 'NN'),
#   ('arkit', 'NN'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('function', 'VB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('for', 'IN'),
#   ('mine', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('seem', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('an', 'DT'),
#   ('issue', 'NN'),
#   ('-', ':'),
#   ('works', 'VBZ'),
#   ('just', 'RB'),
#   ('fine.i', 'VBN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('the', 'DT'),
#   ('standard/expected', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('say', 'VB'),
#   ('that', 'IN'),
#   ('i', 'NN'),
#   ('charged', 'VBD'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('overnight', 'VBD'),
#   ('to', 'TO'),
#   ('100', 'CD'),
#   ('%', 'NN'),
#   ('(', '('),
#   ('indicated', 'VBN'),
#   (')', ')'),
#   (',', ','),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('left', 'VBD'),
#   ('it', 'PRP'),
#   ('turned', 'VBD'),
#   ('on', 'IN'),
#   ('at', 'IN'),
#   ('home', 'NN'),
#   (',', ','),
#   ('connected', 'VBN'),
#   ('to', 'TO'),
#   ('wi-fi', 'NNS'),
#   ('in', 'IN'),
#   ('terms', 'NNS'),
#   ('of', 'IN'),
#   ('using', 'VBG'),
#   ('signal', 'JJ'),
#   ('in', 'IN'),
#   ('any', 'DT'),
#   ('way', 'NN'),
#   (';', ':'),
#   ('after', 'IN'),
#   ('about', 'IN'),
#   ('a', 'DT'),
#   ('10-hour', 'JJ'),
#   ('workday', 'NN'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('came', 'VBD'),
#   ('home', 'RB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('down', 'RB'),
#   ('to', 'TO'),
#   ('85', 'CD'),
#   ('%', 'NN'),
#   ('.', '.'),
#   ('again', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('sure', 'JJ'),
#   ('how', 'WRB'),
#   ('this', 'DT'),
#   ('measures', 'VBZ'),
#   ('up', 'RP'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('healthy', 'JJ'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('tell', 'VB'),
#   ('you', 'PRP'),
#   ('how', 'WRB'),
#   ('thirsty', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('under', 'IN'),
#   ('load', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('unit', 'NN'),
#   ('in', 'IN'),
#   ('standby', 'NN'),
#   ('that', 'IN'),
#   ('feels', 'NNS'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('normal', 'JJ'),
#   ('drain', 'NN'),
#   ('?', '.')],
#  [('phone', 'NN'),
#   ('looked', 'VBD'),
#   ('new', 'JJ'),
#   ('to', 'TO'),
#   ('me', 'PRP'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('been', 'VBN'),
#   ('a', 'DT'),
#   ('landline', 'NN'),
#   ('users', 'NNS'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('pup', 'NN'),
#   ('.', '.'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ("'s", 'POS'),
#   ('pretty', 'JJ'),
#   ('easy', 'JJ'),
#   ('to', 'TO'),
#   ('setup', 'VB'),
#   ('too', 'RB'),
#   ('.', '.'),
#   ('hardest', 'JJS'),
#   ('part', 'NN'),
#   ('(', '('),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   (')', ')'),
#   ('was', 'VBD'),
#   ('getting', 'VBG'),
#   ('the', 'DT'),
#   ('sim', 'NN'),
#   ('chip', 'NN'),
#   ('holder', 'NN'),
#   ('out', 'IN'),
#   ('.', '.'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('put', 'VB'),
#   ('the', 'DT'),
#   ('card', 'NN'),
#   ('in', 'IN'),
#   ('backwards', 'NNS'),
#   ('.', '.'),
#   ('so', 'RB'),
#   ('many', 'JJ'),
#   ('seem', 'VBP'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('this', 'DT'),
#   ('model', 'NN'),
#   ('of', 'IN'),
#   ('iphone', 'NN'),
#   ('.', '.'),
#   ('finding', 'VBG'),
#   ('my', 'PRP$'),
#   ('way', 'NN'),
#   ('around', 'IN'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('&', 'CC'),
#   ('setting', 'NN'),
#   ('things', 'NNS'),
#   ('up', 'RB'),
#   ('.', '.'),
#   ('carrier', 'NN'),
#   ('i', 'NN'),
#   ('signed', 'VBD'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('was', 'VBD'),
#   ('also', 'RB'),
#   ('super', 'JJ'),
#   ('helpful', 'NN'),
#   ('with', 'IN'),
#   ('setting', 'VBG'),
#   ('phone', 'NN'),
#   ('up', 'RB'),
#   ('&', 'CC'),
#   ('porting', 'VBG'),
#   ('my', 'PRP$'),
#   ('old', 'JJ'),
#   ('phone', 'NN'),
#   ('number', 'NN'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('give', 'VB'),
#   ('review', 'NN'),
#   ('stars', 'NNS'),
#   ('for', 'IN'),
#   ('everything', 'NN'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('no', 'DT'),
#   ('idea', 'NN'),
#   ('about', 'IN'),
#   ('battery', 'JJ'),
#   ('life', 'NN'),
#   ('or', 'CC'),
#   ('longevity', 'NN'),
#   (',', ','),
#   ('well', 'UH'),
#   ('its', 'PRP$'),
#   ('worked', 'JJ'),
#   ('fine', 'NN'),
#   ('for', 'IN'),
#   ('3', 'CD'),
#   ('days', 'NNS'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('phone', 'NN'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('absolutely', 'RB'),
#   ('amazing', 'JJ'),
#   ('!', '.'),
#   ('it', 'PRP'),
#   ('did', 'VBD'),
#   ('come', 'VB'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('blemishes/scratches', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   (',', ','),
#   ('but', 'CC'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('painted', 'VBN'),
#   ('over', 'IN'),
#   ('and', 'CC'),
#   ('i', 'JJ'),
#   ('don', 'NN'),
#   ('’', 'NN'),
#   ('t', 'NN'),
#   ('really', 'RB'),
#   ('mind', 'VB'),
#   ('due', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('fact', 'NN'),
#   ('i', 'NN'),
#   ('will', 'MD'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('case', 'NN'),
#   ('covering', 'VBG'),
#   ('it', 'PRP'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('skeptical', 'JJ'),
#   ('at', 'IN'),
#   ('first', 'JJ'),
#   ('when', 'WRB'),
#   ('getting', 'VBG'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ('because', 'IN'),
#   ('the', 'DT'),
#   ('price', 'NN'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('good', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('true', 'JJ'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('had', 'VBN'),
#   ('it', 'PRP'),
#   ('two', 'CD'),
#   ('almost', 'RB'),
#   ('three', 'CD'),
#   ('full', 'JJ'),
#   ('weeks', 'NNS'),
#   ('and', 'CC'),
#   ('everything', 'NN'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('working', 'VBG'),
#   ('just', 'RB'),
#   ('fine', 'JJ'),
#   ('.', '.'),
#   ('the', 'DT'),
#   ('only', 'JJ'),
#   ('bad', 'JJ'),
#   ('thing', 'NN'),
#   ('about', 'IN'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('maximum', 'JJ'),
#   ('battery', 'NN'),
#   ('space', 'NN'),
#   ('is', 'VBZ'),
#   ('76', 'CD'),
#   ('%', 'NN'),
#   ('which', 'WDT'),
#   ('honestly', 'RB'),
#   ('is', 'VBZ'),
#   ('expected', 'VBN'),
#   ('for', 'IN'),
#   ('such', 'PDT'),
#   ('a', 'DT'),
#   ('low', 'JJ'),
#   ('cost', 'NN'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('definitely', 'RB'),
#   ('buy', 'VB'),
#   ('this', 'DT'),
#   ('product', 'NN'),
#   ('again', 'RB')],
#  [('the', 'DT'),
#   ("'minor", 'JJ'),
#   ('visual', 'JJ'),
#   ('blemishes', 'NNS'),
#   ("'", 'POS'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('were', 'VBD'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('case', 'NN'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('scuffed', 'JJ'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('if', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('just', 'RB'),
#   ('paint', 'JJ'),
#   ('peeling', 'NN'),
#   ('or', 'CC'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('refurbishing', 'VBG'),
#   ('company', 'NN'),
#   ('polished', 'VBD'),
#   ('it', 'PRP'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('rough', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('touch', 'NN'),
#   ('or', 'CC'),
#   ('anything', 'NN'),
#   (';', ':'),
#   ('just', 'RB'),
#   ('kinda', 'VB'),
#   ('spotted', 'VBN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('smooth', 'JJ'),
#   ('factory-new', 'JJ'),
#   ('finish.functionally', 'RB'),
#   (',', ','),
#   ('though', 'IN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('perfect', 'JJ'),
#   ('.', '.'),
#   ('they', 'PRP'),
#   ('replaced', 'VBD'),
#   (',', ','),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   (',', ','),
#   ('the', 'DT'),
#   ('display', 'NN'),
#   ('specifically', 'RB'),
#   ('?', '.'),
#   ('because', 'IN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('settings', 'NNS'),
#   ('menu', 'VBP'),
#   ('there', 'EX'),
#   ("'s", 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('warning', 'NN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ("'screen", 'NN'),
#   ('may', 'MD'),
#   ('not', 'RB'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('certified', 'JJ'),
#   ('part', 'NN'),
#   ("'", 'POS'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ('mean', 'NN'),
#   (',', ','),
#   ('okay', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('like', 'IN'),
#   ('i', 'JJ'),
#   ("'m", 'VBP'),
#   ('gon', 'VBG'),
#   ('na', 'TO'),
#   ('try', 'VB'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('a', 'DT'),
#   ('warranty', 'NN'),
#   ('replacement', 'NN'),
#   ('on', 'IN'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('right', 'RB'),
#   ('?', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('heard/read', 'VBN'),
#   ('things', 'NNS'),
#   ('about', 'IN'),
#   ('that', 'DT'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('camera', 'NN'),
#   ('(', '('),
#   ('s', 'NN'),
#   (')', ')'),
#   ('are', 'VBP'),
#   ('replaced', 'VBN'),
#   (',', ','),
#   ('faceid', 'JJ'),
#   ('and/or', 'NN'),
#   ('arkit', 'NN'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('function', 'VB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('for', 'IN'),
#   ('mine', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('seem', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('an', 'DT'),
#   ('issue', 'NN'),
#   ('-', ':'),
#   ('works', 'VBZ'),
#   ('just', 'RB'),
#   ('fine.i', 'VBN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('the', 'DT'),
#   ('standard/expected', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('say', 'VB'),
#   ('that', 'IN'),
#   ('i', 'NN'),
#   ('charged', 'VBD'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('overnight', 'VBD'),
#   ('to', 'TO'),
#   ('100', 'CD'),
#   ('%', 'NN'),
#   ('(', '('),
#   ('indicated', 'VBN'),
#   (')', ')'),
#   (',', ','),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('left', 'VBD'),
#   ('it', 'PRP'),
#   ('turned', 'VBD'),
#   ('on', 'IN'),
#   ('at', 'IN'),
#   ('home', 'NN'),
#   (',', ','),
#   ('connected', 'VBN'),
#   ('to', 'TO'),
#   ('wi-fi', 'NNS'),
#   ('in', 'IN'),
#   ('terms', 'NNS'),
#   ('of', 'IN'),
#   ('using', 'VBG'),
#   ('signal', 'JJ'),
#   ('in', 'IN'),
#   ('any', 'DT'),
#   ('way', 'NN'),
#   (';', ':'),
#   ('after', 'IN'),
#   ('about', 'IN'),
#   ('a', 'DT'),
#   ('10-hour', 'JJ'),
#   ('workday', 'NN'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('came', 'VBD'),
#   ('home', 'RB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('down', 'RB'),
#   ('to', 'TO'),
#   ('85', 'CD'),
#   ('%', 'NN'),
#   ('.', '.'),
#   ('again', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('sure', 'JJ'),
#   ('how', 'WRB'),
#   ('this', 'DT'),
#   ('measures', 'VBZ'),
#   ('up', 'RP'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('healthy', 'JJ'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('tell', 'VB'),
#   ('you', 'PRP'),
#   ('how', 'WRB'),
#   ('thirsty', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('under', 'IN'),
#   ('load', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('unit', 'NN'),
#   ('in', 'IN'),
#   ('standby', 'NN'),
#   ('that', 'IN'),
#   ('feels', 'NNS'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('normal', 'JJ'),
#   ('drain', 'NN'),
#   ('?', '.')],
#  [('phone', 'NN'),
#   ('looked', 'VBD'),
#   ('new', 'JJ'),
#   ('to', 'TO'),
#   ('me', 'PRP'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('been', 'VBN'),
#   ('a', 'DT'),
#   ('landline', 'NN'),
#   ('users', 'NNS'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('pup', 'NN'),
#   ('.', '.'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ("'s", 'POS'),
#   ('pretty', 'JJ'),
#   ('easy', 'JJ'),
#   ('to', 'TO'),
#   ('setup', 'VB'),
#   ('too', 'RB'),
#   ('.', '.'),
#   ('hardest', 'JJS'),
#   ('part', 'NN'),
#   ('(', '('),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   (')', ')'),
#   ('was', 'VBD'),
#   ('getting', 'VBG'),
#   ('the', 'DT'),
#   ('sim', 'NN'),
#   ('chip', 'NN'),
#   ('holder', 'NN'),
#   ('out', 'IN'),
#   ('.', '.'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('put', 'VB'),
#   ('the', 'DT'),
#   ('card', 'NN'),
#   ('in', 'IN'),
#   ('backwards', 'NNS'),
#   ('.', '.'),
#   ('so', 'RB'),
#   ('many', 'JJ'),
#   ('seem', 'VBP'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('this', 'DT'),
#   ('model', 'NN'),
#   ('of', 'IN'),
#   ('iphone', 'NN'),
#   ('.', '.'),
#   ('finding', 'VBG'),
#   ('my', 'PRP$'),
#   ('way', 'NN'),
#   ('around', 'IN'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('&', 'CC'),
#   ('setting', 'NN'),
#   ('things', 'NNS'),
#   ('up', 'RB'),
#   ('.', '.'),
#   ('carrier', 'NN'),
#   ('i', 'NN'),
#   ('signed', 'VBD'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('was', 'VBD'),
#   ('also', 'RB'),
#   ('super', 'JJ'),
#   ('helpful', 'NN'),
#   ('with', 'IN'),
#   ('setting', 'VBG'),
#   ('phone', 'NN'),
#   ('up', 'RB'),
#   ('&', 'CC'),
#   ('porting', 'VBG'),
#   ('my', 'PRP$'),
#   ('old', 'JJ'),
#   ('phone', 'NN'),
#   ('number', 'NN'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('give', 'VB'),
#   ('review', 'NN'),
#   ('stars', 'NNS'),
#   ('for', 'IN'),
#   ('everything', 'NN'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('no', 'DT'),
#   ('idea', 'NN'),
#   ('about', 'IN'),
#   ('battery', 'JJ'),
#   ('life', 'NN'),
#   ('or', 'CC'),
#   ('longevity', 'NN'),
#   (',', ','),
#   ('well', 'UH'),
#   ('its', 'PRP$'),
#   ('worked', 'JJ'),
#   ('fine', 'NN'),
#   ('for', 'IN'),
#   ('3', 'CD'),
#   ('days', 'NNS'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('phone', 'NN'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('absolutely', 'RB'),
#   ('amazing', 'JJ'),
#   ('!', '.'),
#   ('it', 'PRP'),
#   ('did', 'VBD'),
#   ('come', 'VB'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('blemishes/scratches', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   (',', ','),
#   ('but', 'CC'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('painted', 'VBN'),
#   ('over', 'IN'),
#   ('and', 'CC'),
#   ('i', 'JJ'),
#   ('don', 'NN'),
#   ('’', 'NN'),
#   ('t', 'NN'),
#   ('really', 'RB'),
#   ('mind', 'VB'),
#   ('due', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('fact', 'NN'),
#   ('i', 'NN'),
#   ('will', 'MD'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('case', 'NN'),
#   ('covering', 'VBG'),
#   ('it', 'PRP'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('skeptical', 'JJ'),
#   ('at', 'IN'),
#   ('first', 'JJ'),
#   ('when', 'WRB'),
#   ('getting', 'VBG'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ('because', 'IN'),
#   ('the', 'DT'),
#   ('price', 'NN'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('good', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('true', 'JJ'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('had', 'VBN'),
#   ('it', 'PRP'),
#   ('two', 'CD'),
#   ('almost', 'RB'),
#   ('three', 'CD'),
#   ('full', 'JJ'),
#   ('weeks', 'NNS'),
#   ('and', 'CC'),
#   ('everything', 'NN'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('working', 'VBG'),
#   ('just', 'RB'),
#   ('fine', 'JJ'),
#   ('.', '.'),
#   ('the', 'DT'),
#   ('only', 'JJ'),
#   ('bad', 'JJ'),
#   ('thing', 'NN'),
#   ('about', 'IN'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('maximum', 'JJ'),
#   ('battery', 'NN'),
#   ('space', 'NN'),
#   ('is', 'VBZ'),
#   ('76', 'CD'),
#   ('%', 'NN'),
#   ('which', 'WDT'),
#   ('honestly', 'RB'),
#   ('is', 'VBZ'),
#   ('expected', 'VBN'),
#   ('for', 'IN'),
#   ('such', 'PDT'),
#   ('a', 'DT'),
#   ('low', 'JJ'),
#   ('cost', 'NN'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('definitely', 'RB'),
#   ('buy', 'VB'),
#   ('this', 'DT'),
#   ('product', 'NN'),
#   ('again', 'RB')],
#  [('siri', 'NN'),
#   ('does', 'VBZ'),
#   ("n't", 'RB'),
#   ('work', 'VB'),
#   (',', ','),
#   ('cosmetically', 'RB'),
#   ('great', 'JJ'),
#   ('besides', 'IN'),
#   ('the', 'DT'),
#   ('ear', 'JJ'),
#   ('speaker', 'NN'),
#   ('broken', 'VBN'),
#   ('out', 'RP'),
#   ('.', '.'),
#   ('has', 'VBZ'),
#   ('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('i', 'VBP'),
#   ('am', 'VBP'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('phone', 'NN'),
#   ('constantly', 'RB'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('lasts', 'VBZ'),
#   ('all', 'DT'),
#   ('day', 'NN'),
#   ('long', 'RB'),
#   ('.', '.'),
#   ('face', 'NN'),
#   ('recognition', 'NN'),
#   ('works', 'VBZ'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('supposed', 'VBN'),
#   ('to', 'TO'),
#   ('!', '.'),
#   ('but', 'CC'),
#   ('like', 'IN'),
#   ('i', 'NN'),
#   ('said', 'VBD'),
#   ('siri', 'NN'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('work', 'VB'),
#   (',', ','),
#   ('that', 'IN'),
#   ('causes', 'VBZ'),
#   ('issues', 'NNS'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('hands', 'NNS'),
#   ('free', 'VB'),
#   ('while', 'IN'),
#   ('i', 'JJ'),
#   ('am', 'VBP'),
#   ('driving', 'VBG'),
#   ('or', 'CC'),
#   ('washing', 'VBG'),
#   ('dishes', 'NNS'),
#   ('.', '.'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('an', 'DT'),
#   ('inconvenience', 'NN'),
#   ('but', 'CC'),
#   ('just', 'RB'),
#   ('thought', 'VBN'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('say', 'VB'),
#   ('something', 'NN'),
#   ('so', 'RB'),
#   ('maybe', 'RB'),
#   ('it', 'PRP'),
#   ('does', 'VBZ'),
#   ("n't", 'RB'),
#   ('happen', 'VB'),
#   ('to', 'TO'),
#   ('someone', 'NN'),
#   ('else', 'RB'),
#   ('.', '.')],
#  [('the', 'DT'),
#   ("'minor", 'JJ'),
#   ('visual', 'JJ'),
#   ('blemishes', 'NNS'),
#   ("'", 'POS'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('were', 'VBD'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('case', 'NN'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('scuffed', 'JJ'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('if', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('just', 'RB'),
#   ('paint', 'JJ'),
#   ('peeling', 'NN'),
#   ('or', 'CC'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('refurbishing', 'VBG'),
#   ('company', 'NN'),
#   ('polished', 'VBD'),
#   ('it', 'PRP'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('rough', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('touch', 'NN'),
#   ('or', 'CC'),
#   ('anything', 'NN'),
#   (';', ':'),
#   ('just', 'RB'),
#   ('kinda', 'VB'),
#   ('spotted', 'VBN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('smooth', 'JJ'),
#   ('factory-new', 'JJ'),
#   ('finish.functionally', 'RB'),
#   (',', ','),
#   ('though', 'IN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('perfect', 'JJ'),
#   ('.', '.'),
#   ('they', 'PRP'),
#   ('replaced', 'VBD'),
#   (',', ','),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   (',', ','),
#   ('the', 'DT'),
#   ('display', 'NN'),
#   ('specifically', 'RB'),
#   ('?', '.'),
#   ('because', 'IN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('settings', 'NNS'),
#   ('menu', 'VBP'),
#   ('there', 'EX'),
#   ("'s", 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('warning', 'NN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ("'screen", 'NN'),
#   ('may', 'MD'),
#   ('not', 'RB'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('certified', 'JJ'),
#   ('part', 'NN'),
#   ("'", 'POS'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ('mean', 'NN'),
#   (',', ','),
#   ('okay', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('like', 'IN'),
#   ('i', 'JJ'),
#   ("'m", 'VBP'),
#   ('gon', 'VBG'),
#   ('na', 'TO'),
#   ('try', 'VB'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('a', 'DT'),
#   ('warranty', 'NN'),
#   ('replacement', 'NN'),
#   ('on', 'IN'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('right', 'RB'),
#   ('?', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('heard/read', 'VBN'),
#   ('things', 'NNS'),
#   ('about', 'IN'),
#   ('that', 'DT'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('camera', 'NN'),
#   ('(', '('),
#   ('s', 'NN'),
#   (')', ')'),
#   ('are', 'VBP'),
#   ('replaced', 'VBN'),
#   (',', ','),
#   ('faceid', 'JJ'),
#   ('and/or', 'NN'),
#   ('arkit', 'NN'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('function', 'VB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('for', 'IN'),
#   ('mine', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('seem', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('an', 'DT'),
#   ('issue', 'NN'),
#   ('-', ':'),
#   ('works', 'VBZ'),
#   ('just', 'RB'),
#   ('fine.i', 'VBN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('the', 'DT'),
#   ('standard/expected', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('say', 'VB'),
#   ('that', 'IN'),
#   ('i', 'NN'),
#   ('charged', 'VBD'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('overnight', 'VBD'),
#   ('to', 'TO'),
#   ('100', 'CD'),
#   ('%', 'NN'),
#   ('(', '('),
#   ('indicated', 'VBN'),
#   (')', ')'),
#   (',', ','),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('left', 'VBD'),
#   ('it', 'PRP'),
#   ('turned', 'VBD'),
#   ('on', 'IN'),
#   ('at', 'IN'),
#   ('home', 'NN'),
#   (',', ','),
#   ('connected', 'VBN'),
#   ('to', 'TO'),
#   ('wi-fi', 'NNS'),
#   ('in', 'IN'),
#   ('terms', 'NNS'),
#   ('of', 'IN'),
#   ('using', 'VBG'),
#   ('signal', 'JJ'),
#   ('in', 'IN'),
#   ('any', 'DT'),
#   ('way', 'NN'),
#   (';', ':'),
#   ('after', 'IN'),
#   ('about', 'IN'),
#   ('a', 'DT'),
#   ('10-hour', 'JJ'),
#   ('workday', 'NN'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('came', 'VBD'),
#   ('home', 'RB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('down', 'RB'),
#   ('to', 'TO'),
#   ('85', 'CD'),
#   ('%', 'NN'),
#   ('.', '.'),
#   ('again', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('sure', 'JJ'),
#   ('how', 'WRB'),
#   ('this', 'DT'),
#   ('measures', 'VBZ'),
#   ('up', 'RP'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('healthy', 'JJ'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('tell', 'VB'),
#   ('you', 'PRP'),
#   ('how', 'WRB'),
#   ('thirsty', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('under', 'IN'),
#   ('load', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('unit', 'NN'),
#   ('in', 'IN'),
#   ('standby', 'NN'),
#   ('that', 'IN'),
#   ('feels', 'NNS'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('normal', 'JJ'),
#   ('drain', 'NN'),
#   ('?', '.')],
#  [('phone', 'NN'),
#   ('looked', 'VBD'),
#   ('new', 'JJ'),
#   ('to', 'TO'),
#   ('me', 'PRP'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('been', 'VBN'),
#   ('a', 'DT'),
#   ('landline', 'NN'),
#   ('users', 'NNS'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('pup', 'NN'),
#   ('.', '.'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ("'s", 'POS'),
#   ('pretty', 'JJ'),
#   ('easy', 'JJ'),
#   ('to', 'TO'),
#   ('setup', 'VB'),
#   ('too', 'RB'),
#   ('.', '.'),
#   ('hardest', 'JJS'),
#   ('part', 'NN'),
#   ('(', '('),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   (')', ')'),
#   ('was', 'VBD'),
#   ('getting', 'VBG'),
#   ('the', 'DT'),
#   ('sim', 'NN'),
#   ('chip', 'NN'),
#   ('holder', 'NN'),
#   ('out', 'IN'),
#   ('.', '.'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('put', 'VB'),
#   ('the', 'DT'),
#   ('card', 'NN'),
#   ('in', 'IN'),
#   ('backwards', 'NNS'),
#   ('.', '.'),
#   ('so', 'RB'),
#   ('many', 'JJ'),
#   ('seem', 'VBP'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('this', 'DT'),
#   ('model', 'NN'),
#   ('of', 'IN'),
#   ('iphone', 'NN'),
#   ('.', '.'),
#   ('finding', 'VBG'),
#   ('my', 'PRP$'),
#   ('way', 'NN'),
#   ('around', 'IN'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('&', 'CC'),
#   ('setting', 'NN'),
#   ('things', 'NNS'),
#   ('up', 'RB'),
#   ('.', '.'),
#   ('carrier', 'NN'),
#   ('i', 'NN'),
#   ('signed', 'VBD'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('was', 'VBD'),
#   ('also', 'RB'),
#   ('super', 'JJ'),
#   ('helpful', 'NN'),
#   ('with', 'IN'),
#   ('setting', 'VBG'),
#   ('phone', 'NN'),
#   ('up', 'RB'),
#   ('&', 'CC'),
#   ('porting', 'VBG'),
#   ('my', 'PRP$'),
#   ('old', 'JJ'),
#   ('phone', 'NN'),
#   ('number', 'NN'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('give', 'VB'),
#   ('review', 'NN'),
#   ('stars', 'NNS'),
#   ('for', 'IN'),
#   ('everything', 'NN'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('no', 'DT'),
#   ('idea', 'NN'),
#   ('about', 'IN'),
#   ('battery', 'JJ'),
#   ('life', 'NN'),
#   ('or', 'CC'),
#   ('longevity', 'NN'),
#   (',', ','),
#   ('well', 'UH'),
#   ('its', 'PRP$'),
#   ('worked', 'JJ'),
#   ('fine', 'NN'),
#   ('for', 'IN'),
#   ('3', 'CD'),
#   ('days', 'NNS'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('phone', 'NN'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('absolutely', 'RB'),
#   ('amazing', 'JJ'),
#   ('!', '.'),
#   ('it', 'PRP'),
#   ('did', 'VBD'),
#   ('come', 'VB'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('blemishes/scratches', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   (',', ','),
#   ('but', 'CC'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('painted', 'VBN'),
#   ('over', 'IN'),
#   ('and', 'CC'),
#   ('i', 'JJ'),
#   ('don', 'NN'),
#   ('’', 'NN'),
#   ('t', 'NN'),
#   ('really', 'RB'),
#   ('mind', 'VB'),
#   ('due', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('fact', 'NN'),
#   ('i', 'NN'),
#   ('will', 'MD'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('case', 'NN'),
#   ('covering', 'VBG'),
#   ('it', 'PRP'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('skeptical', 'JJ'),
#   ('at', 'IN'),
#   ('first', 'JJ'),
#   ('when', 'WRB'),
#   ('getting', 'VBG'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ('because', 'IN'),
#   ('the', 'DT'),
#   ('price', 'NN'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('good', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('true', 'JJ'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('had', 'VBN'),
#   ('it', 'PRP'),
#   ('two', 'CD'),
#   ('almost', 'RB'),
#   ('three', 'CD'),
#   ('full', 'JJ'),
#   ('weeks', 'NNS'),
#   ('and', 'CC'),
#   ('everything', 'NN'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('working', 'VBG'),
#   ('just', 'RB'),
#   ('fine', 'JJ'),
#   ('.', '.'),
#   ('the', 'DT'),
#   ('only', 'JJ'),
#   ('bad', 'JJ'),
#   ('thing', 'NN'),
#   ('about', 'IN'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('maximum', 'JJ'),
#   ('battery', 'NN'),
#   ('space', 'NN'),
#   ('is', 'VBZ'),
#   ('76', 'CD'),
#   ('%', 'NN'),
#   ('which', 'WDT'),
#   ('honestly', 'RB'),
#   ('is', 'VBZ'),
#   ('expected', 'VBN'),
#   ('for', 'IN'),
#   ('such', 'PDT'),
#   ('a', 'DT'),
#   ('low', 'JJ'),
#   ('cost', 'NN'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('definitely', 'RB'),
#   ('buy', 'VB'),
#   ('this', 'DT'),
#   ('product', 'NN'),
#   ('again', 'RB')],
#  [('siri', 'NN'),
#   ('does', 'VBZ'),
#   ("n't", 'RB'),
#   ('work', 'VB'),
#   (',', ','),
#   ('cosmetically', 'RB'),
#   ('great', 'JJ'),
#   ('besides', 'IN'),
#   ('the', 'DT'),
#   ('ear', 'JJ'),
#   ('speaker', 'NN'),
#   ('broken', 'VBN'),
#   ('out', 'RP'),
#   ('.', '.'),
#   ('has', 'VBZ'),
#   ('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('i', 'VBP'),
#   ('am', 'VBP'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('phone', 'NN'),
#   ('constantly', 'RB'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('lasts', 'VBZ'),
#   ('all', 'DT'),
#   ('day', 'NN'),
#   ('long', 'RB'),
#   ('.', '.'),
#   ('face', 'NN'),
#   ('recognition', 'NN'),
#   ('works', 'VBZ'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('supposed', 'VBN'),
#   ('to', 'TO'),
#   ('!', '.'),
#   ('but', 'CC'),
#   ('like', 'IN'),
#   ('i', 'NN'),
#   ('said', 'VBD'),
#   ('siri', 'NN'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('work', 'VB'),
#   (',', ','),
#   ('that', 'IN'),
#   ('causes', 'VBZ'),
#   ('issues', 'NNS'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('hands', 'NNS'),
#   ('free', 'VB'),
#   ('while', 'IN'),
#   ('i', 'JJ'),
#   ('am', 'VBP'),
#   ('driving', 'VBG'),
#   ('or', 'CC'),
#   ('washing', 'VBG'),
#   ('dishes', 'NNS'),
#   ('.', '.'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('an', 'DT'),
#   ('inconvenience', 'NN'),
#   ('but', 'CC'),
#   ('just', 'RB'),
#   ('thought', 'VBN'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('say', 'VB'),
#   ('something', 'NN'),
#   ('so', 'RB'),
#   ('maybe', 'RB'),
#   ('it', 'PRP'),
#   ('does', 'VBZ'),
#   ("n't", 'RB'),
#   ('happen', 'VB'),
#   ('to', 'TO'),
#   ('someone', 'NN'),
#   ('else', 'RB'),
#   ('.', '.')],
#  [('it', 'PRP'),
#   ('started', 'VBD'),
#   ('out', 'RP'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('bad', 'JJ'),
#   ('situation', 'NN'),
#   ('because', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ("n't", 'RB'),
#   ('sure', 'JJ'),
#   ('if', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('my', 'PRP$'),
#   ('phone', 'NN'),
#   ('or', 'CC'),
#   ('a', 'DT'),
#   ('refund', 'NN'),
#   ('.', '.'),
#   ('originally', 'RB'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('suppose', 'JJ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('delivered', 'VBN'),
#   ('then', 'RB'),
#   (',', ','),
#   ('all', 'DT'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('sudden', 'JJ'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('late', 'RB'),
#   (',', ','),
#   ('then', 'RB'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('possibility', 'NN'),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('been', 'VBN'),
#   ('returned', 'VBN'),
#   ('to', 'TO'),
#   ('seller', 'VB'),
#   ('due', 'JJ'),
#   ('to', 'TO'),
#   ('it', 'PRP'),
#   ('not', 'RB'),
#   ('being', 'VBG'),
#   ('deliver', 'VB'),
#   ('for', 'IN'),
#   ('5', 'CD'),
#   ('days', 'NNS'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('ended', 'VBD'),
#   ('up', 'RP'),
#   ('picking', 'VBG'),
#   ('it', 'PRP'),
#   ('up', 'IN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('shipping', 'NN'),
#   ('place', 'NN'),
#   ('.', '.'),
#   ('after', 'IN'),
#   ('i', 'NN'),
#   ('received', 'VBD'),
#   ('it', 'PRP'),
#   (';', ':'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('exactly', 'RB'),
#   ('as', 'IN'),
#   ('advertised', 'JJ'),
#   ('and', 'CC'),
#   ('in', 'IN'),
#   ('excellent', 'JJ'),
#   ('condition', 'NN'),
#   ('.', '.'),
#   ('so', 'RB'),
#   (',', ','),
#   ('i', 'JJ'),
#   ("'m", 'VBP'),
#   ('so', 'RB'),
#   ('glad', 'JJ'),
#   ('it', 'PRP'),
#   ('turned', 'VBD'),
#   ('out', 'RP'),
#   ('good', 'JJ'),
#   ('..', 'NN'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('definitely', 'RB'),
#   ('grateful', 'JJ'),
#   ('..', 'NN')],
#  [('the', 'DT'),
#   ("'minor", 'JJ'),
#   ('visual', 'JJ'),
#   ('blemishes', 'NNS'),
#   ("'", 'POS'),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   ('were', 'VBD'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('case', 'NN'),
#   ('are', 'VBP'),
#   ('a', 'DT'),
#   ('bit', 'NN'),
#   ('scuffed', 'JJ'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('if', 'IN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('just', 'RB'),
#   ('paint', 'JJ'),
#   ('peeling', 'NN'),
#   ('or', 'CC'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('refurbishing', 'VBG'),
#   ('company', 'NN'),
#   ('polished', 'VBD'),
#   ('it', 'PRP'),
#   ('at', 'IN'),
#   ('all', 'DT'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('rough', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('touch', 'NN'),
#   ('or', 'CC'),
#   ('anything', 'NN'),
#   (';', ':'),
#   ('just', 'RB'),
#   ('kinda', 'VB'),
#   ('spotted', 'VBN'),
#   ('and', 'CC'),
#   ('not', 'RB'),
#   ('a', 'DT'),
#   ('smooth', 'JJ'),
#   ('factory-new', 'JJ'),
#   ('finish.functionally', 'RB'),
#   (',', ','),
#   ('though', 'IN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('perfect', 'JJ'),
#   ('.', '.'),
#   ('they', 'PRP'),
#   ('replaced', 'VBD'),
#   (',', ','),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   (',', ','),
#   ('the', 'DT'),
#   ('display', 'NN'),
#   ('specifically', 'RB'),
#   ('?', '.'),
#   ('because', 'IN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('settings', 'NNS'),
#   ('menu', 'VBP'),
#   ('there', 'EX'),
#   ("'s", 'VBZ'),
#   ('a', 'DT'),
#   ('little', 'JJ'),
#   ('warning', 'NN'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ("'screen", 'NN'),
#   ('may', 'MD'),
#   ('not', 'RB'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('certified', 'JJ'),
#   ('part', 'NN'),
#   ("'", 'POS'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ('mean', 'NN'),
#   (',', ','),
#   ('okay', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('like', 'IN'),
#   ('i', 'JJ'),
#   ("'m", 'VBP'),
#   ('gon', 'VBG'),
#   ('na', 'TO'),
#   ('try', 'VB'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('a', 'DT'),
#   ('warranty', 'NN'),
#   ('replacement', 'NN'),
#   ('on', 'IN'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('right', 'RB'),
#   ('?', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('heard/read', 'VBN'),
#   ('things', 'NNS'),
#   ('about', 'IN'),
#   ('that', 'DT'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('camera', 'NN'),
#   ('(', '('),
#   ('s', 'NN'),
#   (')', ')'),
#   ('are', 'VBP'),
#   ('replaced', 'VBN'),
#   (',', ','),
#   ('faceid', 'JJ'),
#   ('and/or', 'NN'),
#   ('arkit', 'NN'),
#   ('wo', 'MD'),
#   ("n't", 'RB'),
#   ('function', 'VB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('for', 'IN'),
#   ('mine', 'NN'),
#   (',', ','),
#   ('that', 'WDT'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('seem', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('an', 'DT'),
#   ('issue', 'NN'),
#   ('-', ':'),
#   ('works', 'VBZ'),
#   ('just', 'RB'),
#   ('fine.i', 'VBN'),
#   ('do', 'VBP'),
#   ("n't", 'RB'),
#   ('know', 'VB'),
#   ('the', 'DT'),
#   ('standard/expected', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NN'),
#   ('can', 'MD'),
#   ('say', 'VB'),
#   ('that', 'IN'),
#   ('i', 'NN'),
#   ('charged', 'VBD'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('overnight', 'VBD'),
#   ('to', 'TO'),
#   ('100', 'CD'),
#   ('%', 'NN'),
#   ('(', '('),
#   ('indicated', 'VBN'),
#   (')', ')'),
#   (',', ','),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('left', 'VBD'),
#   ('it', 'PRP'),
#   ('turned', 'VBD'),
#   ('on', 'IN'),
#   ('at', 'IN'),
#   ('home', 'NN'),
#   (',', ','),
#   ('connected', 'VBN'),
#   ('to', 'TO'),
#   ('wi-fi', 'NNS'),
#   ('in', 'IN'),
#   ('terms', 'NNS'),
#   ('of', 'IN'),
#   ('using', 'VBG'),
#   ('signal', 'JJ'),
#   ('in', 'IN'),
#   ('any', 'DT'),
#   ('way', 'NN'),
#   (';', ':'),
#   ('after', 'IN'),
#   ('about', 'IN'),
#   ('a', 'DT'),
#   ('10-hour', 'JJ'),
#   ('workday', 'NN'),
#   (',', ','),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('came', 'VBD'),
#   ('home', 'RB'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('down', 'RB'),
#   ('to', 'TO'),
#   ('85', 'CD'),
#   ('%', 'NN'),
#   ('.', '.'),
#   ('again', 'RB'),
#   (',', ','),
#   ('not', 'RB'),
#   ('sure', 'JJ'),
#   ('how', 'WRB'),
#   ('this', 'DT'),
#   ('measures', 'VBZ'),
#   ('up', 'RP'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('healthy', 'JJ'),
#   ('unit', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('tell', 'VB'),
#   ('you', 'PRP'),
#   ('how', 'WRB'),
#   ('thirsty', 'JJ'),
#   ('it', 'PRP'),
#   ('is', 'VBZ'),
#   ('under', 'IN'),
#   ('load', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('unit', 'NN'),
# ...
#   ('to', 'TO'),
#   ('me', 'PRP'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ("'ve", 'VBP'),
#   ('been', 'VBN'),
#   ('a', 'DT'),
#   ('landline', 'NN'),
#   ('users', 'NNS'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('pup', 'NN'),
#   ('.', '.'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ("'s", 'POS'),
#   ('pretty', 'JJ'),
#   ('easy', 'JJ'),
#   ('to', 'TO'),
#   ('setup', 'VB'),
#   ('too', 'RB'),
#   ('.', '.'),
#   ('hardest', 'JJS'),
#   ('part', 'NN'),
#   ('(', '('),
#   ('for', 'IN'),
#   ('me', 'PRP'),
#   (')', ')'),
#   ('was', 'VBD'),
#   ('getting', 'VBG'),
#   ('the', 'DT'),
#   ('sim', 'NN'),
#   ('chip', 'NN'),
#   ('holder', 'NN'),
#   ('out', 'IN'),
#   ('.', '.'),
#   ('and', 'CC'),
#   ('then', 'RB'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('put', 'VB'),
#   ('the', 'DT'),
#   ('card', 'NN'),
#   ('in', 'IN'),
#   ('backwards', 'NNS'),
#   ('.', '.'),
#   ('so', 'RB'),
#   ('many', 'JJ'),
#   ('seem', 'VBP'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('this', 'DT'),
#   ('model', 'NN'),
#   ('of', 'IN'),
#   ('iphone', 'NN'),
#   ('.', '.'),
#   ('finding', 'VBG'),
#   ('my', 'PRP$'),
#   ('way', 'NN'),
#   ('around', 'IN'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('&', 'CC'),
#   ('setting', 'NN'),
#   ('things', 'NNS'),
#   ('up', 'RB'),
#   ('.', '.'),
#   ('carrier', 'NN'),
#   ('i', 'NN'),
#   ('signed', 'VBD'),
#   ('up', 'RP'),
#   ('with', 'IN'),
#   ('was', 'VBD'),
#   ('also', 'RB'),
#   ('super', 'JJ'),
#   ('helpful', 'NN'),
#   ('with', 'IN'),
#   ('setting', 'VBG'),
#   ('phone', 'NN'),
#   ('up', 'RB'),
#   ('&', 'CC'),
#   ('porting', 'VBG'),
#   ('my', 'PRP$'),
#   ('old', 'JJ'),
#   ('phone', 'NN'),
#   ('number', 'NN'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('did', 'VBD'),
#   ("n't", 'RB'),
#   ('give', 'VB'),
#   ('review', 'NN'),
#   ('stars', 'NNS'),
#   ('for', 'IN'),
#   ('everything', 'NN'),
#   ('since', 'IN'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('no', 'DT'),
#   ('idea', 'NN'),
#   ('about', 'IN'),
#   ('battery', 'JJ'),
#   ('life', 'NN'),
#   ('or', 'CC'),
#   ('longevity', 'NN'),
#   (',', ','),
#   ('well', 'UH'),
#   ('its', 'PRP$'),
#   ('worked', 'JJ'),
#   ('fine', 'NN'),
#   ('for', 'IN'),
#   ('3', 'CD'),
#   ('days', 'NNS'),
#   ('.', '.')],
#  [('this', 'DT'),
#   ('phone', 'NN'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('absolutely', 'RB'),
#   ('amazing', 'JJ'),
#   ('!', '.'),
#   ('it', 'PRP'),
#   ('did', 'VBD'),
#   ('come', 'VB'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('blemishes/scratches', 'NNS'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('edges', 'NNS'),
#   (',', ','),
#   ('but', 'CC'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('painted', 'VBN'),
#   ('over', 'IN'),
#   ('and', 'CC'),
#   ('i', 'JJ'),
#   ('don', 'NN'),
#   ('’', 'NN'),
#   ('t', 'NN'),
#   ('really', 'RB'),
#   ('mind', 'VB'),
#   ('due', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('fact', 'NN'),
#   ('i', 'NN'),
#   ('will', 'MD'),
#   ('have', 'VB'),
#   ('a', 'DT'),
#   ('case', 'NN'),
#   ('covering', 'VBG'),
#   ('it', 'PRP'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('skeptical', 'JJ'),
#   ('at', 'IN'),
#   ('first', 'JJ'),
#   ('when', 'WRB'),
#   ('getting', 'VBG'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ('because', 'IN'),
#   ('the', 'DT'),
#   ('price', 'NN'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('good', 'VB'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('true', 'JJ'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NNS'),
#   ('have', 'VBP'),
#   ('had', 'VBN'),
#   ('it', 'PRP'),
#   ('two', 'CD'),
#   ('almost', 'RB'),
#   ('three', 'CD'),
#   ('full', 'JJ'),
#   ('weeks', 'NNS'),
#   ('and', 'CC'),
#   ('everything', 'NN'),
#   ('seems', 'VBZ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('working', 'VBG'),
#   ('just', 'RB'),
#   ('fine', 'JJ'),
#   ('.', '.'),
#   ('the', 'DT'),
#   ('only', 'JJ'),
#   ('bad', 'JJ'),
#   ('thing', 'NN'),
#   ('about', 'IN'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('maximum', 'JJ'),
#   ('battery', 'NN'),
#   ('space', 'NN'),
#   ('is', 'VBZ'),
#   ('76', 'CD'),
#   ('%', 'NN'),
#   ('which', 'WDT'),
#   ('honestly', 'RB'),
#   ('is', 'VBZ'),
#   ('expected', 'VBN'),
#   ('for', 'IN'),
#   ('such', 'PDT'),
#   ('a', 'DT'),
#   ('low', 'JJ'),
#   ('cost', 'NN'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('definitely', 'RB'),
#   ('buy', 'VB'),
#   ('this', 'DT'),
#   ('product', 'NN'),
#   ('again', 'RB')],
#  [('siri', 'NN'),
#   ('does', 'VBZ'),
#   ("n't", 'RB'),
#   ('work', 'VB'),
#   (',', ','),
#   ('cosmetically', 'RB'),
#   ('great', 'JJ'),
#   ('besides', 'IN'),
#   ('the', 'DT'),
#   ('ear', 'JJ'),
#   ('speaker', 'NN'),
#   ('broken', 'VBN'),
#   ('out', 'RP'),
#   ('.', '.'),
#   ('has', 'VBZ'),
#   ('great', 'JJ'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('i', 'VBP'),
#   ('am', 'VBP'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('phone', 'NN'),
#   ('constantly', 'RB'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('lasts', 'VBZ'),
#   ('all', 'DT'),
#   ('day', 'NN'),
#   ('long', 'RB'),
#   ('.', '.'),
#   ('face', 'NN'),
#   ('recognition', 'NN'),
#   ('works', 'VBZ'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('supposed', 'VBN'),
#   ('to', 'TO'),
#   ('!', '.'),
#   ('but', 'CC'),
#   ('like', 'IN'),
#   ('i', 'NN'),
#   ('said', 'VBD'),
#   ('siri', 'NN'),
#   ('does', 'VBZ'),
#   ('not', 'RB'),
#   ('work', 'VB'),
#   (',', ','),
#   ('that', 'IN'),
#   ('causes', 'VBZ'),
#   ('issues', 'NNS'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('do', 'VB'),
#   ('hands', 'NNS'),
#   ('free', 'VB'),
#   ('while', 'IN'),
#   ('i', 'JJ'),
#   ('am', 'VBP'),
#   ('driving', 'VBG'),
#   ('or', 'CC'),
#   ('washing', 'VBG'),
#   ('dishes', 'NNS'),
#   ('.', '.'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('an', 'DT'),
#   ('inconvenience', 'NN'),
#   ('but', 'CC'),
#   ('just', 'RB'),
#   ('thought', 'VBN'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('say', 'VB'),
#   ('something', 'NN'),
#   ('so', 'RB'),
#   ('maybe', 'RB'),
#   ('it', 'PRP'),
#   ('does', 'VBZ'),
#   ("n't", 'RB'),
#   ('happen', 'VB'),
#   ('to', 'TO'),
#   ('someone', 'NN'),
#   ('else', 'RB'),
#   ('.', '.')],
#  [('it', 'PRP'),
#   ('started', 'VBD'),
#   ('out', 'RP'),
#   ('as', 'IN'),
#   ('a', 'DT'),
#   ('bad', 'JJ'),
#   ('situation', 'NN'),
#   ('because', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ("n't", 'RB'),
#   ('sure', 'JJ'),
#   ('if', 'IN'),
#   ('i', 'NN'),
#   ('was', 'VBD'),
#   ('going', 'VBG'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('my', 'PRP$'),
#   ('phone', 'NN'),
#   ('or', 'CC'),
#   ('a', 'DT'),
#   ('refund', 'NN'),
#   ('.', '.'),
#   ('originally', 'RB'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('suppose', 'JJ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('delivered', 'VBN'),
#   ('then', 'RB'),
#   (',', ','),
#   ('all', 'DT'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('sudden', 'JJ'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('late', 'RB'),
#   (',', ','),
#   ('then', 'RB'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('a', 'DT'),
#   ('possibility', 'NN'),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('been', 'VBN'),
#   ('returned', 'VBN'),
#   ('to', 'TO'),
#   ('seller', 'VB'),
#   ('due', 'JJ'),
#   ('to', 'TO'),
#   ('it', 'PRP'),
#   ('not', 'RB'),
#   ('being', 'VBG'),
#   ('deliver', 'VB'),
#   ('for', 'IN'),
#   ('5', 'CD'),
#   ('days', 'NNS'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('ended', 'VBD'),
#   ('up', 'RP'),
#   ('picking', 'VBG'),
#   ('it', 'PRP'),
#   ('up', 'IN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('shipping', 'NN'),
#   ('place', 'NN'),
#   ('.', '.'),
#   ('after', 'IN'),
#   ('i', 'NN'),
#   ('received', 'VBD'),
#   ('it', 'PRP'),
#   (';', ':'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('exactly', 'RB'),
#   ('as', 'IN'),
#   ('advertised', 'JJ'),
#   ('and', 'CC'),
#   ('in', 'IN'),
#   ('excellent', 'JJ'),
#   ('condition', 'NN'),
#   ('.', '.'),
#   ('so', 'RB'),
#   (',', ','),
#   ('i', 'JJ'),
#   ("'m", 'VBP'),
#   ('so', 'RB'),
#   ('glad', 'JJ'),
#   ('it', 'PRP'),
#   ('turned', 'VBD'),
#   ('out', 'RP'),
#   ('good', 'JJ'),
#   ('..', 'NN'),
#   ('i', 'NN'),
#   ('am', 'VBP'),
#   ('definitely', 'RB'),
#   ('grateful', 'JJ'),
#   ('..', 'NN')],
#  [('i', 'NN'),
#   ('was', 'VBD'),
#   ('little', 'JJ'),
#   ('hesitant', 'JJ'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('refurbished', 'VBN'),
#   ('phone', 'NN'),
#   ('.', '.'),
#   ('this', 'DT'),
#   ('was', 'VBD'),
#   ('my', 'PRP$'),
#   ('first', 'JJ'),
#   ('time', 'NN'),
#   ('buying', 'NN'),
#   ('refurbished', 'VBD'),
#   ('phone', 'NN'),
#   ('and', 'CC'),
#   ('i', 'NN'),
#   ('’', 'VBP'),
#   ('m', 'NN'),
#   ('pretty', 'RB'),
#   ('happy', 'JJ'),
#   ('with', 'IN'),
#   ('it', 'PRP'),
#   ('!', '.'),
#   ('it', 'PRP'),
#   ('looks', 'VBZ'),
#   ('and', 'CC'),
#   ('acts', 'VBZ'),
#   ('like', 'IN'),
#   ('brand', 'NN'),
#   ('new', 'JJ'),
#   ('!', '.'),
#   ('the', 'DT'),
#   ('only', 'JJ'),
#   ('thing', 'NN'),
#   ('i', 'NN'),
#   ('’', 'VBP'),
#   ('ll', 'NN'),
#   ('will', 'MD'),
#   ('give', 'VB'),
#   ('it', 'PRP'),
#   ('a', 'DT'),
#   ('4', 'CD'),
#   ('star', 'NN'),
#   ('review', 'NN'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('battery', 'NN'),
#   ('health', 'NN'),
#   ('mine', 'NN'),
#   ('is', 'VBZ'),
#   ('at', 'IN'),
#   ('86', 'CD'),
#   ('%', 'NN'),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('good', 'JJ'),
#   ('i', 'NN'),
#   ('guess', 'NN'),
#   ('i', 'NN'),
#   ('would', 'MD'),
#   ('’', 'VB'),
#   ('ve', 'IN'),
#   ('like', 'IN'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('at', 'IN'),
#   ('least', 'JJS'),
#   ('89', 'CD'),
#   ('%', 'NN'),
#   ('but', 'CC'),
#   ('beggars', 'NNS'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('be', 'VB'),
#   ('choosers', 'NNS'),
#   ('.', '.')],
#  [('it', 'PRP'),
#   ('has', 'VBZ'),
#   ('taken', 'VBN'),
#   ('me', 'PRP'),
#   ('some', 'DT'),
#   ('time', 'NN'),
#   ('getting', 'VBG'),
#   ('use', 'NN'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('phone11', 'NN'),
#   (';', ':'),
#   ('i', 'NN'),
#   ('had', 'VBD'),
#   ('an', 'DT'),
#   ('se', 'NN'),
#   ('.', '.'),
#   ('the', 'DT'),
#   ('reason', 'NN'),
#   ('i', 'NN'),
#   ('updated', 'VBD'),
#   ('was', 'VBD'),
#   ('my', 'PRP$'),
#   ('battery', 'NN'),
#   ('ran', 'VBD'),
#   ('down', 'RB'),
#   ('by', 'IN'),
#   ('4:00', 'CD'),
#   ('pm', 'JJ'),
#   ('every', 'DT'),
#   ('day', 'NN'),
#   ('after', 'IN'),
#   ('a', 'DT'),
#   ('full', 'JJ'),
#   ('10', 'CD'),
#   ('hr', 'NN'),
#   ('night', 'NN'),
#   ('charge', 'NN'),
#   ('.', '.'),
#   ('this', 'DT'),
#   ('phone', 'NN'),
#   ('makes', 'VBZ'),
#   ('it', 'PRP'),
#   ('to', 'TO'),
#   ('5:00', 'CD'),
#   (';', ':'),
#   ('i', 'NN'),
#   ('expected', 'VBD'),
#   ('to', 'TO'),
#   ('hold', 'VB'),
#   ('the', 'DT'),
#   ('charge', 'NN'),
#   ('longer', 'RB'),
#   ('.', '.'),
#   ('that', 'DT'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('disappointment', 'NN'),
#   ('because', 'IN'),
#   ('i', 'JJ'),
#   ('thought', 'JJ'),
#   ('literature', 'NN'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('battery', 'NN'),
#   ('was', 'VBD'),
#   ('better', 'JJR'),
#   ('than', 'IN'),
#   ('9', 'CD'),
#   ('hours', 'NNS'),
#   ('.', '.')],
#  [('we', 'PRP'),
#   ('had', 'VBD'),
#   ('to', 'TO'),
#   ('purchase', 'VB'),
#   ('our', 'PRP$'),
#   ('daughter', 'NN'),
#   ('a', 'DT'),
#   ('new', 'JJ'),
#   ('phone', 'NN'),
#   ('last', 'JJ'),
#   ('minute', 'NN'),
#   ('seeing', 'VBG'),
#   ('as', 'IN'),
#   ('hers', 'NNS'),
#   ('fell', 'VBD'),
#   ('off', 'RP'),
#   ('the', 'DT'),
#   ('counter', 'NN'),
#   ('and', 'CC'),
#   ('broke', 'NN'),
#   (',', ','),
#   ('she', 'PRP'),
#   ('could', 'MD'),
#   ("n't", 'RB'),
#   ('use', 'VB'),
#   ('it', 'PRP'),
#   ('because', 'IN'),
#   ('the', 'DT'),
#   ('touch', 'JJ'),
#   ('screen', 'NN'),
#   ('got', 'VBD'),
#   ('broke', 'RB'),
#   ('.', '.'),
#   ('anyway', 'RB'),
#   (',', ','),
#   ('instead', 'RB'),
#   ('of', 'IN'),
#   ('getting', 'VBG'),
#   ('the', 'DT'),
#   ('same', 'JJ'),
#   ('model', 'NN'),
#   ('we', 'PRP'),
#   ('upgraded', 'VBD'),
#   ('her', 'PRP'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('mint', 'NN'),
#   ('apple', 'NN'),
#   ('iphone', 'NN'),
#   ('11', 'CD'),
#   (',', ','),
#   ('we', 'PRP'),
#   ('just', 'RB'),
#   ('received', 'VBD'),
#   ('it', 'PRP'),
#   ('today', 'NN'),
#   ('so', 'RB'),
#   ('ca', 'MD'),
#   ("n't", 'RB'),
#   ('comment', 'VB'),
#   ('on', 'IN'),
#   ('how', 'WRB'),
#   ('it', 'PRP'),
#   ('operates', 'VBZ'),
#   ('much', 'RB'),
#   ('yet', 'RB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('i', 'NNS'),
#   ('do', 'VBP'),
#   ('want', 'VB'),
#   ('to', 'TO'),
#   ('say', 'VB'),
#   ('that', 'IN'),
#   ('she', 'PRP'),
#   ("'s", 'VBZ'),
#   ('absolutely', 'RB'),
#   ('in', 'IN'),
#   ('love', 'NN'),
#   ('with', 'IN'),
#   ('it', 'PRP'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('color', 'NN'),
#   ('!', '.'),
#   ('the', 'DT'),
#   ('seller', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('swift', 'JJ'),
#   ('at', 'IN'),
#   ('replying', 'VBG'),
#   ('to', 'TO'),
#   ('my', 'PRP$'),
#   ('questions', 'NNS'),
#   ('and', 'CC'),
#   ('inquiries', 'NNS'),
#   ('on', 'IN'),
#   ('it', 'PRP'),
#   (',', ','),
#   ('they', 'PRP'),
#   ('went', 'VBD'),
#   ('above', 'IN'),
#   ('and', 'CC'),
#   ('beyond', 'IN'),
#   ('!', '.'),
#   ('!', '.'),
#   ('!', '.'),
#   ('also', 'RB'),
#   (',', ','),
#   ('they', 'PRP'),
#   ('shipped', 'VBD'),
#   ('it', 'PRP'),
#   ('right', 'VBD'),
#   ('out', 'RP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('we', 'PRP'),
#   ('got', 'VBD'),
#   ('it', 'PRP'),
#   ('two', 'CD'),
#   ('days', 'NNS'),
#   ('sooner', 'RB'),
#   ('then', 'RB'),
#   ('amazon', 'NN'),
#   ('said', 'VBD'),
#   ('we', 'PRP'),
#   ('would', 'MD'),
#   ('receive', 'VB'),
#   ('it', 'PRP'),
#   ('!', '.'),
#   ('5', 'CD'),
#   ('stars', 'NNS'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('seller', 'NN'),
#   ('!', '.'),
#   ('!', '.'),
#   ('!', '.')],
#  [('i', 'NN'),
#   ('was', 'VBD'),
#   ('very', 'RB'),
#   ('hesitant', 'JJ'),
#   ('on', 'IN'),
#   ('making', 'VBG'),
#   ('this', 'DT'),
#   ('purchase', 'NN'),
#   ('after', 'IN'),
#   ('reading', 'VBG'),
#   ('the', 'DT'),
#   ('reviews', 'NNS'),
#   ('.', '.'),
#   ('however', 'RB'),
#   (',', ','),
#   ('i', 'JJ'),
#   ('bought', 'VBD'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('and', 'CC'),
#   ('received', 'VBD'),
#   ('it', 'PRP'),
#   ('in', 'IN'),
#   ('great', 'JJ'),
#   ('condition', 'NN'),
#   ('.', '.'),
#   ('the', 'DT'),
#   ('battery', 'NN'),
#   ('health', 'NN'),
#   ('is', 'VBZ'),
#   ('good', 'JJ'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('quality', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('camera', 'NN'),
#   ('is', 'VBZ'),
#   ('good', 'JJ'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('bought', 'VBD'),
#   ('it', 'PRP'),
#   ('last', 'JJ'),
#   ('month', 'NN'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('phone', 'NN'),
#   ('is', 'VBZ'),
#   ('functioning', 'VBG'),
#   ('well', 'RB'),
#   ('.', '.')],
#  [('shipping', 'NN'),
#   ('was', 'VBD'),
#   ('quick', 'JJ'),
#   ('and', 'CC'),
#   ('excellent', 'JJ'),
#   ('shape', 'NN'),
#   ('described', 'VBD'),
#   ('it', 'PRP'),
#   ('perfectly', 'RB'),
#   ('.', '.'),
#   ('my', 'PRP$'),
#   ('wife', 'NN'),
#   ('bought', 'VBD'),
#   ('an', 'DT'),
#   ('iphone', 'NN'),
#   ('12', 'CD'),
#   ('shortly', 'RB'),
#   ('after', 'IN'),
#   ('my', 'PRP$'),
#   ('purchase', 'NN'),
#   ('that', 'DT'),
#   ('was', 'VBD'),
#   ('also', 'RB'),
#   ('supposed', 'VBN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('excellent', 'JJ'),
#   ('shape', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('it', 'PRP'),
#   ('had', 'VBD'),
#   ('more', 'RBR'),
#   ('noticeable', 'JJ'),
#   ('defects', 'NNS'),
#   ('than', 'IN'),
#   ('my', 'PRP$'),
#   ('refurbished', 'JJ'),
#   ('11', 'CD'),
#   ('so', 'IN'),
#   ('it', 'PRP'),
#   ('made', 'VBD'),
#   ('me', 'PRP'),
#   ('really', 'RB'),
#   ('happy', 'JJ'),
#   ('about', 'IN'),
#   ('my', 'PRP$'),
#   ('purchase', 'NN'),
#   ('.', '.'),
#   ('i', 'JJ'),
#   ('think', 'VBP'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('some', 'DT'),
#   ('variation', 'NN'),
#   ('in', 'IN'),
#   ('what', 'WP'),
#   ('some', 'DT'),
#   ('people', 'NNS'),
#   ('call', 'VBP'),
#   ('excellent', 'JJ'),
#   (',', ','),
#   ('so', 'IN'),
#   ('you', 'PRP'),
#   ('kind', 'NN'),
#   ('of', 'IN'),
#   ('hope', 'NN'),
#   ('to', 'TO'),
#   ('get', 'VB'),
#   ('lucky', 'JJ'),
#   ('and', 'CC'),
#   ('have', 'VBP'),
#   ('one', 'CD'),
#   ('that', 'WDT'),
#   ('someone', 'NN'),
#   ('took', 'VBD'),
#   ('extra', 'RB'),
#   ('good', 'JJ'),
#   ('care', 'NN'),
#   ('of', 'IN'),
#   ('.', '.'),
#   ('battery', 'NN'),
#   ('life', 'NN'),
#   ('on', 'IN'),
#   ('my', 'PRP$'),
#   ('11', 'CD'),
#   ('is', 'VBZ'),
#   ('amazing', 'VBG'),
#   ('!', '.'),
#   ('even', 'RB'),
#   ('though', 'IN'),
#   ('it', 'PRP'),
#   ('says', 'VBZ'),
#   ('86', 'CD'),
#   ('%', 'NN'),
#   ('life', 'NN'),
#   (',', ','),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ('had', 'VBD'),
#   ('it', 'PRP'),
#   ('go', 'VB'),
#   ('3', 'CD'),
#   ('full', 'JJ'),
#   ('days', 'NNS'),
#   ('between', 'IN'),
#   ('charges', 'NNS'),
#   ('on', 'IN'),
#   ('occasion', 'NN'),
#   ('when', 'WRB'),
#   ('i', 'NN'),
#   ('have', 'VBP'),
#   ("n't", 'RB'),
#   ('used', 'VBN'),
#   ('it', 'PRP'),
#   ('for', 'IN'),
#   ('watching', 'VBG'),
#   ('things', 'NNS'),
#   ('.', '.')]]

# %%
from collections import Counter
counts = []
for tags in pos:
  count = Counter( tag for word,  tag in tags)
  counts.append(count)
counts
# Out:
# [Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'PRP': 18,
#           'VBD': 11,
#           'TO': 5,
#           'VB': 6,
#           'PRP$': 2,
#           'NN': 16,
#           'DT': 8,
#           'JJ': 5,
#           'VBG': 3,
#           'IN': 11,
#           'NNS': 6,
#           'RP': 2,
#           'CC': 6,
#           ',': 7,
#           'MD': 3,
#           'RB': 14,
#           '.': 9,
#           'CD': 3,
#           'WRB': 1,
#           'VBZ': 2,
#           'VBP': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'PRP': 18,
#           'VBD': 11,
#           'TO': 5,
#           'VB': 6,
#           'PRP$': 2,
#           'NN': 16,
#           'DT': 8,
#           'JJ': 5,
#           'VBG': 3,
#           'IN': 11,
#           'NNS': 6,
#           'RP': 2,
#           'CC': 6,
#           ',': 7,
#           'MD': 3,
#           'RB': 14,
#           '.': 9,
#           'CD': 3,
#           'WRB': 1,
#           'VBZ': 2,
#           'VBP': 1}),
#  Counter({'NN': 11,
#           'VBD': 4,
#           'RB': 3,
#           'JJ': 6,
#           'IN': 4,
#           'VBG': 3,
#           'DT': 7,
#           'NNS': 1,
#           '.': 4,
#           ',': 1,
#           'CC': 3,
#           'PRP': 2,
#           'VBZ': 3}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'PRP': 18,
#           'VBD': 11,
#           'TO': 5,
#           'VB': 6,
#           'PRP$': 2,
#           'NN': 16,
#           'DT': 8,
#           'JJ': 5,
#           'VBG': 3,
#           'IN': 11,
#           'NNS': 6,
#           'RP': 2,
#           'CC': 6,
#           ',': 7,
#           'MD': 3,
#           'RB': 14,
#           '.': 9,
#           'CD': 3,
#           'WRB': 1,
#           'VBZ': 2,
#           'VBP': 1}),
#  Counter({'NN': 11,
#           'VBD': 4,
#           'RB': 3,
#           'JJ': 6,
#           'IN': 4,
#           'VBG': 3,
#           'DT': 7,
#           'NNS': 1,
#           '.': 4,
#           ',': 1,
#           'CC': 3,
#           'PRP': 2,
#           'VBZ': 3}),
#  Counter({'NN': 19,
#           'VBD': 8,
#           'JJ': 11,
#           'CC': 3,
#           'PRP': 8,
#           'RB': 7,
#           '.': 5,
#           'PRP$': 5,
#           'DT': 4,
#           'CD': 6,
#           'IN': 13,
#           'VBN': 2,
#           'TO': 2,
#           'VB': 3,
#           ',': 3,
#           'RBR': 1,
#           'NNS': 5,
#           'VBP': 5,
#           'EX': 1,
#           'VBZ': 3,
#           'WP': 1,
#           'WDT': 1,
#           'VBG': 2,
#           'WRB': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'PRP': 18,
#           'VBD': 11,
#           'TO': 5,
#           'VB': 6,
#           'PRP$': 2,
#           'NN': 16,
#           'DT': 8,
#           'JJ': 5,
#           'VBG': 3,
#           'IN': 11,
#           'NNS': 6,
#           'RP': 2,
#           'CC': 6,
#           ',': 7,
#           'MD': 3,
#           'RB': 14,
#           '.': 9,
#           'CD': 3,
#           'WRB': 1,
#           'VBZ': 2,
#           'VBP': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'PRP': 18,
#           'VBD': 11,
#           'TO': 5,
#           'VB': 6,
#           'PRP$': 2,
#           'NN': 16,
#           'DT': 8,
#           'JJ': 5,
#           'VBG': 3,
#           'IN': 11,
#           'NNS': 6,
#           'RP': 2,
#           'CC': 6,
#           ',': 7,
#           'MD': 3,
#           'RB': 14,
#           '.': 9,
#           'CD': 3,
#           'WRB': 1,
#           'VBZ': 2,
#           'VBP': 1}),
#  Counter({'NN': 11,
#           'VBD': 4,
#           'RB': 3,
#           'JJ': 6,
#           'IN': 4,
#           'VBG': 3,
#           'DT': 7,
#           'NNS': 1,
#           '.': 4,
#           ',': 1,
#           'CC': 3,
#           'PRP': 2,
#           'VBZ': 3}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'PRP': 18,
#           'VBD': 11,
#           'TO': 5,
#           'VB': 6,
#           'PRP$': 2,
#           'NN': 16,
#           'DT': 8,
#           'JJ': 5,
#           'VBG': 3,
#           'IN': 11,
#           'NNS': 6,
#           'RP': 2,
#           'CC': 6,
#           ',': 7,
#           'MD': 3,
#           'RB': 14,
#           '.': 9,
#           'CD': 3,
#           'WRB': 1,
#           'VBZ': 2,
#           'VBP': 1}),
#  Counter({'NN': 11,
#           'VBD': 4,
#           'RB': 3,
#           'JJ': 6,
#           'IN': 4,
#           'VBG': 3,
#           'DT': 7,
#           'NNS': 1,
#           '.': 4,
#           ',': 1,
#           'CC': 3,
#           'PRP': 2,
#           'VBZ': 3}),
#  Counter({'NN': 19,
#           'VBD': 8,
#           'JJ': 11,
#           'CC': 3,
#           'PRP': 8,
#           'RB': 7,
#           '.': 5,
#           'PRP$': 5,
#           'DT': 4,
#           'CD': 6,
#           'IN': 13,
#           'VBN': 2,
#           'TO': 2,
#           'VB': 3,
#           ',': 3,
#           'RBR': 1,
#           'NNS': 5,
#           'VBP': 5,
#           'EX': 1,
#           'VBZ': 3,
#           'WP': 1,
#           'WDT': 1,
#           'VBG': 2,
#           'WRB': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
# ...
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'PRP': 18,
#           'VBD': 11,
#           'TO': 5,
#           'VB': 6,
#           'PRP$': 2,
#           'NN': 16,
#           'DT': 8,
#           'JJ': 5,
#           'VBG': 3,
#           'IN': 11,
#           'NNS': 6,
#           'RP': 2,
#           'CC': 6,
#           ',': 7,
#           'MD': 3,
#           'RB': 14,
#           '.': 9,
#           'CD': 3,
#           'WRB': 1,
#           'VBZ': 2,
#           'VBP': 1}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'PRP': 18,
#           'VBD': 11,
#           'TO': 5,
#           'VB': 6,
#           'PRP$': 2,
#           'NN': 16,
#           'DT': 8,
#           'JJ': 5,
#           'VBG': 3,
#           'IN': 11,
#           'NNS': 6,
#           'RP': 2,
#           'CC': 6,
#           ',': 7,
#           'MD': 3,
#           'RB': 14,
#           '.': 9,
#           'CD': 3,
#           'WRB': 1,
#           'VBZ': 2,
#           'VBP': 1}),
#  Counter({'NN': 11,
#           'VBD': 4,
#           'RB': 3,
#           'JJ': 6,
#           'IN': 4,
#           'VBG': 3,
#           'DT': 7,
#           'NNS': 1,
#           '.': 4,
#           ',': 1,
#           'CC': 3,
#           'PRP': 2,
#           'VBZ': 3}),
#  Counter({'DT': 26,
#           'JJ': 22,
#           'NNS': 7,
#           'POS': 2,
#           'IN': 29,
#           'PRP': 10,
#           'VBD': 10,
#           'NN': 37,
#           'VBP': 8,
#           '.': 7,
#           'RB': 21,
#           'VB': 11,
#           'VBZ': 7,
#           'CC': 9,
#           'VBG': 3,
#           ',': 19,
#           'TO': 8,
#           ':': 3,
#           'VBN': 6,
#           'EX': 1,
#           'MD': 4,
#           '(': 2,
#           ')': 2,
#           'JJS': 1,
#           'WDT': 1,
#           'CD': 2,
#           'WRB': 3,
#           'RP': 1}),
#  Counter({'NN': 30,
#           'VBD': 7,
#           'JJ': 9,
#           'TO': 4,
#           'PRP': 2,
#           '.': 9,
#           'VBP': 3,
#           'VBN': 1,
#           'DT': 8,
#           'NNS': 5,
#           'IN': 12,
#           'POS': 1,
#           'VB': 4,
#           'RB': 7,
#           'JJS': 1,
#           '(': 1,
#           ')': 1,
#           'VBG': 5,
#           'CC': 4,
#           'PRP$': 3,
#           'RP': 1,
#           ',': 1,
#           'UH': 1,
#           'CD': 1}),
#  Counter({'DT': 12,
#           'NN': 19,
#           'VBZ': 6,
#           'VBN': 4,
#           'RB': 8,
#           'JJ': 13,
#           '.': 4,
#           'PRP': 4,
#           'VBD': 3,
#           'VB': 7,
#           'IN': 8,
#           'NNS': 4,
#           ',': 2,
#           'CC': 4,
#           'TO': 4,
#           'MD': 2,
#           'VBG': 3,
#           'WRB': 1,
#           'VBP': 1,
#           'CD': 3,
#           'WDT': 1,
#           'PDT': 1}),
#  Counter({'NN': 18,
#           'VBZ': 9,
#           'RB': 10,
#           'VB': 6,
#           ',': 3,
#           'JJ': 4,
#           'IN': 5,
#           'DT': 5,
#           'VBN': 3,
#           'RP': 1,
#           '.': 5,
#           'VBP': 4,
#           'PRP$': 1,
#           'CC': 4,
#           'PRP': 3,
#           'TO': 3,
#           'VBD': 1,
#           'NNS': 3,
#           'WRB': 1,
#           'VBG': 3,
#           'MD': 1}),
#  Counter({'PRP': 10,
#           'VBD': 11,
#           'RP': 3,
#           'IN': 10,
#           'DT': 6,
#           'JJ': 11,
#           'NN': 14,
#           'RB': 10,
#           'VBG': 3,
#           'TO': 4,
#           'VB': 4,
#           'PRP$': 1,
#           'CC': 2,
#           '.': 4,
#           'VBN': 3,
#           ',': 3,
#           'CD': 1,
#           'NNS': 1,
#           ':': 1,
#           'VBP': 2}),
#  Counter({'NN': 21,
#           'VBD': 3,
#           'JJ': 7,
#           'TO': 2,
#           'DT': 5,
#           'VBN': 1,
#           '.': 4,
#           'PRP$': 1,
#           'CC': 3,
#           'VBP': 2,
#           'RB': 2,
#           'IN': 6,
#           'PRP': 4,
#           'VBZ': 5,
#           'MD': 3,
#           'VB': 4,
#           'CD': 3,
#           'WDT': 1,
#           'JJS': 1,
#           'NNS': 2}),
#  Counter({'PRP': 3,
#           'VBZ': 3,
#           'VBN': 1,
#           'DT': 11,
#           'NN': 18,
#           'VBG': 1,
#           'TO': 3,
#           ':': 2,
#           'VBD': 7,
#           '.': 4,
#           'PRP$': 1,
#           'RB': 2,
#           'IN': 4,
#           'CD': 4,
#           'JJ': 4,
#           'VB': 1,
#           'JJR': 1,
#           'NNS': 1}),
#  Counter({'PRP': 18,
#           'VBD': 11,
#           'TO': 5,
#           'VB': 6,
#           'PRP$': 2,
#           'NN': 16,
#           'DT': 8,
#           'JJ': 5,
#           'VBG': 3,
#           'IN': 11,
#           'NNS': 6,
#           'RP': 2,
#           'CC': 6,
#           ',': 7,
#           'MD': 3,
#           'RB': 14,
#           '.': 9,
#           'CD': 3,
#           'WRB': 1,
#           'VBZ': 2,
#           'VBP': 1}),
#  Counter({'NN': 11,
#           'VBD': 4,
#           'RB': 3,
#           'JJ': 6,
#           'IN': 4,
#           'VBG': 3,
#           'DT': 7,
#           'NNS': 1,
#           '.': 4,
#           ',': 1,
#           'CC': 3,
#           'PRP': 2,
#           'VBZ': 3}),
#  Counter({'NN': 19,
#           'VBD': 8,
#           'JJ': 11,
#           'CC': 3,
#           'PRP': 8,
#           'RB': 7,
#           '.': 5,
#           'PRP$': 5,
#           'DT': 4,
#           'CD': 6,
#           'IN': 13,
#           'VBN': 2,
#           'TO': 2,
#           'VB': 3,
#           ',': 3,
#           'RBR': 1,
#           'NNS': 5,
#           'VBP': 5,
#           'EX': 1,
#           'VBZ': 3,
#           'WP': 1,
#           'WDT': 1,
#           'VBG': 2,
#           'WRB': 1})]

# %%
# !pip install benepar
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting benepar
#   Downloading benepar-0.2.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.2 in /usr/local/lib/python3.8/dist-packages (from benepar) (3.7)
# Requirement already satisfied: spacy>=2.0.9 in /usr/local/lib/python3.8/dist-packages (from benepar) (3.4.4)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from benepar) (1.13.1+cu116)
# Collecting torch-struct>=0.5
#   Downloading torch_struct-0.5-py3-none-any.whl (34 kB)
# Collecting tokenizers>=0.9.4
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 39.4 MB/s eta 0:00:00
# Collecting transformers[tokenizers,torch]>=4.2.2
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 43.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.8/dist-packages (from benepar) (3.19.6)
# Collecting sentencepiece>=0.1.91
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2->benepar) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2->benepar) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2->benepar) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2->benepar) (8.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (0.7.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (8.1.7)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (3.0.12)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (1.22.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (2.25.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (1.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (1.10.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (3.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (6.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0->benepar) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (6.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=2.0.9->benepar) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=2.0.9->benepar) (0.7.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy>=2.0.9->benepar) (2.1.2)
# Building wheels for collected packages: benepar
#   Building wheel for benepar (setup.py) ... done
#   Created wheel for benepar: filename=benepar-0.2.0-py3-none-any.whl size=37646 sha256=cbe7e2a52f263469879aaef4cd1e2e39f441a4c987fe14840f6eb17fb4c9b19f
#   Stored in directory: /root/.cache/pip/wheels/61/a2/7e/f3631621bc53a802ee5a333d2b1bd0582fd50402cf702b3e37
# Successfully built benepar
# Installing collected packages: tokenizers, sentencepiece, torch-struct, huggingface-hub, transformers, benepar
# Successfully installed benepar-0.2.0 huggingface-hub-0.12.1 sentencepiece-0.1.97 tokenizers-0.13.2 torch-struct-0.5 transformers-4.26.1

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.8/dist-packages (2.11.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (15.0.6.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (23.1.21)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.11.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow) (23.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.51.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.16.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (6.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)

# %%
# !pip install benepar
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: benepar in /usr/local/lib/python3.8/dist-packages (0.2.0)
# Requirement already satisfied: nltk>=3.2 in /usr/local/lib/python3.8/dist-packages (from benepar) (3.7)
# Requirement already satisfied: tokenizers>=0.9.4 in /usr/local/lib/python3.8/dist-packages (from benepar) (0.13.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.8/dist-packages (from benepar) (3.19.6)
# Requirement already satisfied: torch-struct>=0.5 in /usr/local/lib/python3.8/dist-packages (from benepar) (0.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from benepar) (1.13.1+cu116)
# Requirement already satisfied: spacy>=2.0.9 in /usr/local/lib/python3.8/dist-packages (from benepar) (3.4.4)
# Requirement already satisfied: transformers[tokenizers,torch]>=4.2.2 in /usr/local/lib/python3.8/dist-packages (from benepar) (4.26.1)
# Requirement already satisfied: sentencepiece>=0.1.91 in /usr/local/lib/python3.8/dist-packages (from benepar) (0.1.97)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2->benepar) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2->benepar) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2->benepar) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk>=3.2->benepar) (1.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (1.10.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (1.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (57.4.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (1.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (3.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (2.4.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (8.1.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (6.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (0.7.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=2.0.9->benepar) (2.25.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0->benepar) (4.5.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (0.12.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (3.9.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=2.0.9->benepar) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=2.0.9->benepar) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy>=2.0.9->benepar) (2.1.2)

# %%
import sys 
# !{sys.executable} -m pip install tensorflow==2.8.0
import benepar
benepar.download('benepar_en3')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.8.0
#   Downloading tensorflow-2.8.0-cp38-cp38-manylinux2010_x86_64.whl (497.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.5 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (3.1.0)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 73.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (57.4.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (0.4.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (15.0.6.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (1.51.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (0.31.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (1.22.4)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (1.4.0)
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 56.0 MB/s eta 0:00:00
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (3.19.6)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (23.1.21)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (2.2.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 KB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (4.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.8.0) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow==2.8.0) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.16.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.2.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.25.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (6.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8.0) (3.2.2)
# Installing collected packages: tf-estimator-nightly, keras, keras-preprocessing, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# Successfully installed keras-2.8.0 keras-preprocessing-1.1.2 tensorboard-2.8.0 tensorflow-2.8.0 tf-estimator-nightly-2.8.0.dev2021122109
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Unzipping models/benepar_en3.zip.
# True

# %%
import spacy.cli
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import benepar
parser = benepar.Parser("benepar_en3")
for sentence in df['Lower Case']:
  try:
    tree = parser.parse(sentence)
    print(tree)
  except:
    print("No Parse Tree")
    continue
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.8/dist-packages/torch/distributions/distribution.py:45: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(f'{self.__class__} does not define `arg_constraints`. ' +
# Streaming output truncated to the last 5000 lines.
#               (NP (PRP i))
#               (VP
#                 (VBP have)
#                 (VP
#                   (VP
#                     (VBN had)
#                     (NP (PRP it))
#                     (NP
#                       (QP (CD two) (RB almost) (CD three))
#                       (JJ full)
#                       (NNS weeks)))
#                   (CC and)
#                   (S
#                     (NP (NN everything))
#                     (VP
#                       (VBZ seems)
#                       (S
#                         (VP
#                           (TO to)
#                           (VP
#                             (VB be)
#                             (VP (VBG working) (RB just) (JJ fine))))))))))
#             (. .)
#             (NP
#               (NP (DT the) (JJ only) (JJ bad) (NN thing))
#               (PP (IN about) (NP (DT this) (NN phone)))))
#           (VP
#             (VBZ is)
#             (SBAR
#               (IN that)
#               (S
#                 (NP (DT the) (JJ maximum) (NN battery) (NN space))
#                 (VP
#                   (VBZ is)
#                   (NP
#                     (CD 76)
#                     (NN %)
#                     (SBAR
#                       (WHNP (WDT which))
#                       (S
#                         (ADVP (RB honestly))
#                         (VP
#                           (VBZ is)
#                           (VP
#                             (VBN expected)
#                             (PP
#                               (IN for)
#                               (NP
#                                 (JJ such)
#                                 (DT a)
#                                 (JJ low)
#                                 (NN cost)))))))))))))
#         (. .)
#         (NP (PRP i))))
#     (VP
#       (MD would)
#       (ADVP
#         (ADVP (RB definitely))
#         (VP (VB buy) (NP (DT this) (NN product)) (ADVP (RB again)))))))
# (TOP
#   (S
#     (S (NP (NNP siri)) (VP (VBZ does) (RB n't) (VP (VB work))))
#     (, ,)
#     (ADJP (RB cosmetically) (JJ great))
#     (PP
#       (PP
#         (IN besides)
#         (NP
#           (NP (DT the) (NN ear) (NN speaker))
#           (VP (VBN broken) (PRT (RP out)))))
#       (. .)
#       (VP (VBZ has) (NP (JJ great) (NN battery) (NN life))))
#     (, ,)
#     (S
#       (NP (PRP i))
#       (VP
#         (VBP am)
#         (PP (IN on) (NP (PRP$ my) (NN phone)))
#         (ADVP (RB constantly))))
#     (CC and)
#     (S
#       (NP (DT the) (NN battery) (NN life))
#       (VP
#         (VP
#           (VP (VBZ lasts) (ADVP (DT all) (NN day) (RB long)))
#           (. .)
#           (S
#             (NP (NN face) (NN recognition))
#             (VP
#               (VBZ works)
#               (NP
#                 (NP (DT the) (NN way))
#                 (SBAR
#                   (S
#                     (NP (PRP it))
#                     (VP
#                       (VBZ 's)
#                       (VP (VBN supposed) (S (VP (TO to)))))))))))
#         (. !)
#         (CC but)
#         (SBAR
#           (IN like)
#           (S
#             (NP (PRP i))
#             (VP
#               (VBD said)
#               (SBAR
#                 (S
#                   (NP (NNP siri))
#                   (VP (VBZ does) (RB not) (VP (VB work))))))))))
#     (, ,)
#     (NP (DT that))
#     (VP
#       (VP
#         (VP
#           (VBZ causes)
#           (NP (NNS issues))
#           (SBAR
#             (WHADVP (WRB when))
#             (S
#               (NP (PRP i))
#               (VP
#                 (VBP am)
#                 (VP
#                   (VBG trying)
#                   (S
#                     (VP
#                       (S
#                         (VP
#                           (TO to)
#                           (VB do)
#                           (NP (NNS hands))
#                           (S (ADJP (JJ free)))))
#                       (SBAR
#                         (IN while)
#                         (S
#                           (NP (PRP i))
#                           (VP
#                             (VBP am)
#                             (VP
#                               (VP (VBG driving))
#                               (CC or)
#                               (VBG washing)
#                               (NP (NNS dishes)))))))))))))
#         (. .)
#         (NP (PRP it))
#         (VP (VBZ 's) (NP (DT an) (NN inconvenience))))
#       (CC but)
#       (ADVP (RB just))
#       (VP
#         (VBD thought)
#         (SBAR
#           (S
#             (NP (PRP i))
#             (VP
#               (MD would)
#               (VP
#                 (VB say)
#                 (NP (NN something))
#                 (IN so)
#                 (S
#                   (ADVP (RB maybe))
#                   (NP (PRP it))
#                   (VP
#                     (VBZ does)
#                     (RB n't)
#                     (VP
#                       (VB happen)
#                       (PP (IN to) (NP (NN someone) (RB else))))))))))))
#     (. .)))
# (TOP
#   (S
#     (S
#       (NP (PRP it))
#       (VP
#         (VBD started)
#         (PRT (RP out))
#         (PP (IN as) (NP (DT a) (JJ bad) (NN situation)))
#         (SBAR
#           (IN because)
#           (S
#             (NP (PRP i))
#             (VP
#               (VBD was)
#               (RB n't)
#               (ADJP
#                 (JJ sure)
#                 (SBAR
#                   (IN if)
#                   (S
#                     (NP (PRP i))
#                     (VP
#                       (VBD was)
#                       (VP
#                         (VBG going)
#                         (S
#                           (VP
#                             (TO to)
#                             (VP
#                               (VB get)
#                               (NP
#                                 (NP (PRP$ my) (NN phone))
#                                 (CC or)
#                                 (NP (DT a) (NN refund))))))))))))))))
#     (. .)
#     (ADVP (RB originally))
#     (NP (PRP it))
#     (VP
#       (VBD was)
#       (VP
#         (VP
#           (VBN suppose)
#           (S (VP (TO to) (VP (VB be) (VP (VBN delivered))))))
#         (ADVP (RB then))))
#     (, ,)
#     (S
#       (ADVP (NP (DT all)) (PP (IN of) (NP (DT a) (NN sudden))))
#       (NP (PRP it))
#       (VP (VBD was) (ADJP (JJ late))))
#     (, ,)
#     (ADVP (RB then))
#     (NP (PRP it))
#     (VBD was)
#     (DT a)
#     (NN possibility)
#     (SBAR
#       (S
#         (SBAR
#           (S
#             (SBAR
#               (S
#                 (SBAR
#                   (S
#                     (SBAR
#                       (S
#                         (SBAR
#                           (S
#                             (SBAR
#                               (S
#                                 (NP (PRP it))
#                                 (VP
#                                   (VBD had)
#                                   (VP
#                                     (VBN been)
#                                     (VP
#                                       (VBN returned)
#                                       (PP (IN to) (NP (NN seller)))
#                                       (PP
#                                         (IN due)
#                                         (IN to)
#                                         (S
#                                           (NP (PRP it))
#                                           (VP
#                                             (RB not)
#                                             (VP
#                                               (VBG being)
#                                               (VP
#                                                 (VB deliver)
#                                                 (PP
#                                                   (IN for)
#                                                   (NP
#                                                     (CD 5)
#                                                     (NNS days)))))))))))))
#                             (. .)
#                             (S
#                               (NP (PRP i))
#                               (VP
#                                 (VBD ended)
#                                 (PRT (RP up))
#                                 (S
#                                   (VP
#                                     (VBG picking)
#                                     (NP (PRP it))
#                                     (PRT (RP up))
#                                     (PP
#                                       (IN from)
#                                       (NP
#                                         (NP
#                                           (NP
#                                             (DT the)
#                                             (NN shipping)
#                                             (NN place))
#                                           (. .))
#                                         (PP
#                                           (IN after)
#                                           (S
#                                             (NP (PRP i))
#                                             (VP
#                                               (VBD received)
#                                               (NP (PRP it)))))))))))))
#                         (: ;)
#                         (NP (PRP it))))
#                     (VP
#                       (VBD was)
#                       (NP
#                         (PP
#                           (ADVP (RB exactly))
#                           (IN as)
#                           (S (VP (VBN advertised))))
#                         (CC and)
#                         (PP
#                           (IN in)
#                           (NP (JJ excellent) (NN condition)))))))
#                 (. .)
#                 (IN so)))
#             (, ,)
#             (S
#               (NP (PRP i))
#               (VP
#                 (VBP 'm)
#                 (ADJP
#                   (RB so)
#                   (JJ glad)
#                   (SBAR
#                     (S
#                       (SBAR
#                         (S
#                           (SBAR
#                             (S
#                               (SBAR
#                                 (S
#                                   (SBAR
#                                     (S
#                                       (NP (PRP it))
#                                       (VP
#                                         (VBD turned)
#                                         (PRT (RP out))
#                                         (ADJP (JJ good)))))
#                                   (. ..)))
#                               (NP (PRP i))))
#                           (VBP am)))
#                       (ADVP (RB definitely))
#                       (ADJP (JJ grateful)))))))))
#         (: ..)))))
# (TOP
#   (S
#     (S
#       (NP (PRP i))
#       (VP
#         (VP
#           (VBD was)
#           (ADJP
#             (RB little)
#             (JJ hesitant)
#             (PP (IN to) (NP (DT a) (VBN refurbished) (NN phone)))))
#         (. .)
#         (S
#           (NP (DT this))
#           (VP
#             (VBD was)
#             (NP
#               (NP (PRP$ my) (JJ first) (NN time))
#               (VP (VBG buying) (NP (VBN refurbished) (NN phone))))))))
#     (CC and)
#     (S
#       (S
#         (S
#           (NP (PRP i))
#           (VP
#             (VBP ’)
#             (VP
#               (VBP m)
#               (ADJP
#                 (RB pretty)
#                 (JJ happy)
#                 (PP (IN with) (NP (PRP it)))))))
#         (. !)
#         (S
#           (NP (PRP it))
#           (VP
#             (VP
#               (VP (VBZ looks))
#               (CC and)
#               (VP
#                 (VBZ acts)
#                 (PP (IN like) (ADJP (NN brand) (JJ new)))))
#             (. !)
#             (NP
#               (NP (DT the) (JJ only) (NN thing))
#               (SBAR
#                 (S
#                   (PRP i)
#                   (VP
#                     (VBP ’)
#                     (VP
#                       (MD ll)
#                       (VP
#                         (MD will)
#                         (VP
#                           (VB give)
#                           (NP (PRP it))
#                           (NP
#                             (DT a)
#                             (NML (CD 4) (NN star))
#                             (NN review))))))))))))
#       (VP
#         (VBZ is)
#         (NP
#           (NP
#             (NP (DT the) (NN battery) (NN health))
#             (SBAR
#               (S
#                 (NP (PRP mine))
#                 (VBZ is)
#                 (PP (IN at) (NP (CD 86) (NN %))))))
#           (SBAR
#             (WHNP (WDT which))
#             (S
#               (VP
#                 (S (VP (VBZ is) (ADJP (JJ good))))
#                 (SBAR
#                   (S
#                     (NP (PRP i))
#                     (VP
#                       (VP
#                         (VBP guess)
#                         (SBAR
#                           (S
#                             (NP (PRP i))
#                             (VP
#                               (MD would)
#                               (VP
#                                 (VB ’)
#                                 (VP
#                                   (VB ve)
#                                   (VP
#                                     (VB like)
#                                     (S
#                                       (NP (PRP it))
#                                       (VP
#                                         (TO to)
#                                         (VP
#                                           (VB have)
#                                           (NP
#                                             (QP
#                                               (ADVP
#                                                 (RB at)
#                                                 (RBS least))
#                                               (CD 89))
#                                             (NN %))))))))))))
#                       (CC but)
#                       (S
#                         (NP (NNS beggars))
#                         (VP
#                           (MD ca)
#                           (RB n't)
#                           (VP (VB be) (NP (NNS choosers))))))))))))))
#     (. .)))
# (TOP
#   (S
#     (S
#       (NP (PRP it))
#       (VP
#         (VBZ has)
#         (VP
#           (VBN taken)
#           (NP (PRP me))
#           (NP (DT some) (NN time))
#           (S
#             (VP
#               (VBG getting)
#               (NP (NN use))
#               (PP (IN to) (NP (DT this) (CD phone11))))))))
#     (: ;)
#     (S
#       (S
#         (S (NP (PRP i)) (VP (VBD had) (NP (DT an) (NN se))))
#         (-RRB- .)
#         (S
#           (S
#             (NP
#               (NP (DT the) (NN reason))
#               (SBAR (S (NP (PRP i)) (VP (VBD updated)))))
#             (VP
#               (VBD was)
#               (SBAR
#                 (S
#                   (NP (PRP$ my) (NN battery))
#                   (VP
#                     (VBD ran)
#                     (ADVP (RB down))
#                     (PP (IN by) (NP (CD 4:00) (NN pm)))
#                     (NP (DT every) (NN day))
#                     (PP
#                       (IN after)
#                       (NP
#                         (DT a)
#                         (JJ full)
#                         (NML (CD 10) (NN hr))
#                         (NN night)
#                         (NN charge))))))))
#           (. .)
#           (S
#             (NP (DT this) (NN phone))
#             (VP
#               (VBZ makes)
#               (NP (PRP it))
#               (PP (IN to) (NP (CD 5:00)))))))
#       (: ;)
#       (S
#         (NP
#           (S
#             (NP (PRP i))
#             (VP
#               (VBD expected)
#               (S
#                 (VP
#                   (TO to)
#                   (VP
#                     (VB hold)
#                     (NP (DT the) (NN charge))
#                     (ADVP (RBR longer)))))))
#           (. .)
#           (NP (DT that)))
#         (VP
#           (VBZ is)
#           (NP (DT a) (NN disappointment))
#           (SBAR
#             (IN because)
#             (S
#               (NP (PRP i))
#               (VP
#                 (VBD thought)
#                 (SBAR
#                   (S
#                     (NP (NN literature))
#                     (VP
#                       (VBD said)
#                       (SBAR
#                         (S
#                           (NP (DT the) (NN battery))
#                           (VP
#                             (VBD was)
#                             (ADJP
#                               (ADJP (JJR better))
#                               (PP (IN than) (NP (CD 9) (NNS hours))))))))))))))))
#     (. .)))
# (TOP
#   (S
#     (NP
#       (NP (DT the) (JJ 'minor) (JJ visual) (NNS blemishes) (NNS '))
#       (PP (IN for) (NP (PRP me))))
#     (VP
#       (VP
#         (VP
#           (VBD were)
#           (SBAR
#             (IN that)
#             (S
#               (NP
#                 (NP (DT the) (NNS edges))
#                 (PP (IN of) (NP (DT the) (NN case))))
#               (VP
#                 (VBP are)
#                 (ADJP (NP (DT a) (NN bit)) (VBN scuffed))))))
#         (. .)
#         (S
#           (NP (PRP i))
#           (VP
#             (VBP do)
#             (RB n't)
#             (VP
#               (VB know)
#               (SBAR
#                 (SBAR
#                   (IN if)
#                   (S
#                     (NP (PRP it))
#                     (VP
#                       (VBZ 's)
#                       (ADVP (RB just))
#                       (VP (NN paint) (VBG peeling)))))
#                 (CC or)
#                 (SBAR
#                   (IN if)
#                   (S
#                     (NP (DT the) (VBG refurbishing) (NN company))
#                     (VP
#                       (VBD polished)
#                       (NP (PRP it))
#                       (ADVP (RB at) (RB all))))))))))
#       (, ,)
#       (CC but)
#       (S
#         (NP
#           (S
#             (NP (PRP it))
#             (VP
#               (VBZ 's)
#               (RB not)
#               (ADJP
#                 (ADJP (JJ rough))
#                 (PP
#                   (PP (IN to) (NP (DT the) (NN touch)))
#                   (CC or)
#                   (NP (NN anything))))))
#           (: ;)
#           (ADVP
#             (ADVP
#               (ADVP (RB just) (RB kinda))
#               (VP (VBN spotted))
#               (CC and)
#               (ADVP
#                 (RB not)
#                 (ADVP
#                   (NP (DT a) (JJ smooth) (JJ factory-new))
#                   (RB finish.functionally))))
#             (, ,)
#             (ADVP (RB though)))
#           (, ,)
#           (NP
#             (NP
#               (NP (DT the) (NN phone))
#               (VP (VBZ is) (ADJP (JJ perfect)))
#               (. .)
#               (NP (PRP they)))
#             (VBD replaced)
#             (, ,)
#             (NP
#               (INTJ (NP (PRP i)) (VP (VBP think)))
#               (, ,)
#               (NP
#                 (ADVP
#                   (NP (DT the) (NN display))
#                   (ADVP
#                     (ADVP (RB specifically))
#                     (. ?)
#                     (IN because)
#                     (PP
#                       (PP
#                         (PP
#                           (IN in)
#                           (NP
#                             (NP (DT the) (NNS settings) (NN menu))
#                             (NP
#                               (NP (EX there))
#                               (VBZ 's)
#                               (NP
#                                 (NP (DT a) (JJ little) (NN warning))
#                                 (IN that)
#                                 (S
#                                   (S
#                                     (NP (DT the) (NN 'screen))
#                                     (VP
#                                       (MD may)
#                                       (RB not)
#                                       (VP
#                                         (VB be)
#                                         (NP
#                                           (NP
#                                             (DT a)
#                                             (VBN certified)
#                                             (NN part))
#                                           ('' ')
#                                           (. .)
#                                           (S
#                                             (NP (PRP i))
#                                             (VP
#                                               (VB mean)
#                                               (, ,)
#                                               (INTJ
#                                                 (INTJ (RB okay))
#                                                 (, ,)
#                                                 (RB not)
#                                                 (IN like)
#                                                 (S
#                                                   (NP (PRP i))
#                                                   (VP
#                                                     (VBP 'm)
#                                                     (NP
#                                                       (FW gon)
#                                                       (FW na)
#                                                       (VP
#                                                         (VB try)
#                                                         (S
#                                                           (VP
#                                                             (S
#                                                               (VP
#                                                                 (TO
#                                                                   to)
#                                                                 (VP
#                                                                   (VB
#                                                                     get)
#                                                                   (NP
#                                                                     (NP
#                                                                       (DT
#                                                                         a)
#                                                                       (NN
#                                                                         warranty)
#                                                                       (NN
#                                                                         replacement))
#                                                                     (PP
#                                                                       (IN
#                                                                         on)
#                                                                       (NP
#                                                                         (PRP
#                                                                           it)))))))
#                                                             (, ,)
#                                                             (SINV
#                                                               (ADVP
#                                                                 (RB
#                                                                   right))
#                                                               (. ?)
#                                                               (S
#                                                                 (NP
#                                                                   (PRP
#                                                                     i))
#                                                                 (VP
#                                                                   (VBP
#                                                                     've)
#                                                                   (VP
#                                                                     (VBN
#                                                                       heard/read)
#                                                                     (NP
#                                                                       (NNS
#                                                                         things))
#                                                                     (PP
#                                                                       (PP
#                                                                         (IN
#                                                                           about)
#                                                                         (NP
#                                                                           (IN
#                                                                             that)))
#                                                                       (SBAR
#                                                                         (IN
#                                                                           if)
#                                                                         (S
#                                                                           (NP
#                                                                             (S
#                                                                               (NP
#                                                                                 (NP
#                                                                                   (DT
#                                                                                     the)
#                                                                                   (NN
#                                                                                     camera))
#                                                                                 (-LRB-
#                                                                                   ()
#                                                                                 (NP
#                                                                                   (POS
#                                                                                     s)))
#                                                                               (-RRB-
#                                                                                 ))
#                                                                               (VP
#                                                                                 (VBP
#                                                                                   are)
#                                                                                 (VP
#                                                                                   (VBN
#                                                                                     replaced))))
#                                                                             (,
#                                                                               ,)
#                                                                             (NP
#                                                                               (NP
#                                                                                 (NN
#                                                                                   faceid))
#                                                                               (CC
#                                                                                 and/or)
#                                                                               (NP
#                                                                                 (NN
#                                                                                   arkit))))
#                                                                           (VP
#                                                                             (MD
#                                                                               wo)
#                                                                             (RB
#                                                                               n't)
#                                                                             (VP
#                                                                               (VB
#                                                                                 function)))))))))))))))))))))))
#                                   (, ,)
#                                   (CC but)
#                                   (PP
#                                     (ADVP (RB at) (RBS least))
#                                     (PP (IN for) (NP (PRP mine)))))))))
#                         (, ,)
#                         (NP
#                           (NP (IN that))
#                           (VP
#                             (VBD did)
#                             (RB n't)
#                             (VP
#                               (VB seem)
#                               (S
#                                 (VP
#                                   (TO to)
#                                   (VP
#                                     (VB be)
#                                     (NP (DT an) (NN issue)))))))))
#                       (: -)
#                       (ADVP (VBZ works) (ADVP (RB just))))))
#                 (NP (PRP fine.i))))))
#         (VP
#           (VBP do)
#           (RB n't)
#           (VP
#             (VB know)
#             (NP
#               (NP
#                 (DT the)
#                 (VBN standard/expected)
#                 (NN battery)
#                 (NN life))
#               (, ,)
#               (CC but)
#               (S
#                 (NP (PRP i))
#                 (VP
#                   (MD can)
#                   (VP
#                     (VB say)
#                     (SBAR
#                       (IN that)
#                       (S
#                         (NP (PRP i))
#                         (VP
#                           (VP
#                             (VP
#                               (VBD charged)
#                               (NP (DT the) (NN phone))
#                               (ADVP (RB overnight))
#                               (PP
#                                 (PP
#                                   (PP
#                                     (PP
#                                       (IN to)
#                                       (NP (NP (CD 100)) (CD %)))
#                                     (-LRB- ()
#                                     (S (VP (VBN indicated))))
#                                   (, )))
#                                 (, ,)
#                                 (CC and)
#                                 (ADVP (RB then))
#                                 (VP
#                                   (VBD left)
#                                   (NP (PRP it))
#                                   (S
#                                     (VP
#                                       (VBD turned)
#                                       (PRT (RP on))
#                                       (PP
#                                         (PP (IN at) (NP (NN home)))
#                                         (, ,)
#                                         (S
#                                           (VP
#                                             (VBN connected)
#                                             (PP
#                                               (PP
#                                                 (IN to)
#                                                 (NP (NN wi-fi)))
#                                               (PP
#                                                 (IN in)
#                                                 (NP
#                                                   (NP (NNS terms))
#                                                   (PP
#                                                     (IN of)
#                                                     (S
#                                                       (VP
#                                                         (VBG using)
#                                                         (NP
#                                                           (NN signal))
#                                                         (PP
#                                                           (IN in)
#                                                           (NP
#                                                             (DT any)
#                                                             (NN way)))))))))))))))))
#                             (: ;)
#                             (S
#                               (PP
#                                 (PP
#                                   (IN after)
#                                   (NP
#                                     (IN about)
#                                     (DT a)
#                                     (NN 10-hour)
#                                     (NN workday)))
#                                 (, ,)
#                                 (SBAR
#                                   (WHADVP (WRB when))
#                                   (S
#                                     (NP (PRP i))
#                                     (VP (VBD came) (RB home)))))
#                               (, ,)
#                               (NP (PRP it))
#                               (VP
#                                 (VBD was)
#                                 (ADVP
#                                   (RB down)
#                                   (PP (IN to) (NP (NN 85) (NN %)))))))
#                           (. .)
#                           (ADVP (RB again))
#                           (, ,)
#                           (RB not)
#                           (ADJP
#                             (JJ sure)
#                             (SBAR
#                               (WHADVP (WRB how))
#                               (S
#                                 (NP (DT this))
#                                 (VP
#                                   (VBZ measures)
#                                   (ADVP (RB up))
#                                   (PP
#                                     (PP
#                                       (PP
#                                         (IN to)
#                                         (NP
#                                           (DT a)
#                                           (JJ healthy)
#                                           (NN unit)))
#                                       (, ,))
#                                     (CC and)
#                                     (VP
#                                       (MD ca)
#                                       (RB n't)
#                                       (VP
#                                         (VB tell)
#                                         (NP
#                                           (NP (PRP you))
#                                           (SBAR
#                                             (SBAR
#                                               (WHADVP
#                                                 (WHADVP (WRB how))
#                                                 (JJ thirsty))
#                                               (S
#                                                 (NP (PRP it))
#                                                 (VP
#                                                   (VBZ is)
#                                                   (PP
#                                                     (IN under)
#                                                     (NP (NN load))))))
#                                             (, ,)
#                                             (CC but)
#                                             (PP
#                                               (IN for)
#                                               (NP
#                                                 (NP
#                                                   (NP
#                                                     (NP
#                                                       (DT a)
#                                                       (NN unit))
#                                                     (PP
#                                                       (IN in)
#                                                       (NN standby)))
#                                                   (DT that))
#                                                 (VP
#                                                   (VBZ feels)
#                                                   (PP
#                                                     (IN like)
#                                                     (NP
#                                                       (DT a)
#                                                       (JJ normal)
#                                                       (NN drain))))))))))))))))))))))))))
#     (. ?)))
# (TOP
#   (S
#     (NP (NN phone))
#     (VP
#       (VP (VBD looked) (ADJP (JJ new)) (PP (IN to) (NP (PRP me))))
#       (: .)
#       (S
#         (NP (PRP i))
#         (VP
#           (VBP 've)
#           (VP
#             (VBN been)
#             (NP (DT a) (NN landline) (NNS users))
#             (SBAR
#               (IN since)
#               (S (NP (PRP i)) (VP (VBD was) (NP (DT a) (NN pup)))))))))
#     (: .)
#     (S
#       (S
#         (NP (DT this) (NN phone))
#         (VP
#           (VBZ 's)
#           (ADJP
#             (RB pretty)
#             (JJ easy)
#             (SBAR (S (VP (TO to) (VP (VB setup))))))
#           (ADVP (RB too))))
#       (. .)
#       (S
#         (NP
#           (NP (JJS hardest) (NN part))
#           (-LRB- ()
#           (PP (IN for) (NP (PRP me)))
#           (-RRB- )))
#         (VP
#           (VP
#             (VP
#               (VBD was)
#               (S
#                 (VP
#                   (VBG getting)
#                   (NP (DT the) (NML (NN sim) (NN chip)) (NN holder))
#                   (PRT (RP out)))))
#             (. .)
#             (CC and)
#             (S
#               (ADVP (RB then))
#               (S
#                 (NP (PRP i))
#                 (VP
#                   (VBD was)
#                   (VP
#                     (VBG trying)
#                     (S
#                       (VP
#                         (TO to)
#                         (VP
#                           (VB put)
#                           (NP (DT the) (NN card))
#                           (PRT (IN in))
#                           (NP (NNS backwards))))))))))
#           (: .)
#           (S
#             (NP (ADJP (RB so) (JJ many)))
#             (VP
#               (VBP seem)
#               (S
#                 (VP
#                   (S
#                     (VP
#                       (TO to)
#                       (VP
#                         (VB have)
#                         (NP
#                           (NP (DT this) (NN model))
#                           (PP (IN of) (NP (NN iphone)))))))
#                   (. .)
#                   (VP
#                     (VP
#                       (VBG finding)
#                       (NP (PRP$ my) (NN way))
#                       (PP (IN around) (NP (DT the) (NN phone))))
#                     (CC &)
#                     (VP
#                       (S
#                         (VP
#                           (VP
#                             (VP
#                               (VBG setting)
#                               (NP (NNS things))
#                               (PRT (RP up)))
#                             (. .)
#                             (NP
#                               (NP (NN carrier))
#                               (SBAR
#                                 (S
#                                   (NP (PRP i))
#                                   (VP
#                                     (VBD signed)
#                                     (PRT (RP up))
#                                     (PP (IN with)))))))
#                           (VBD was)))
#                       (ADVP (RB also))
#                       (NP
#                         (RB super)
#                         (JJ helpful)
#                         (PP
#                           (IN with)
#                           (S
#                             (VP
#                               (VBG setting)
#                               (NP (NN phone))
#                               (PRT (RP up))
#                               (CC &)
#                               (VP
#                                 (VBG porting)
#                                 (NP
#                                   (NP
#                                     (PRP$ my)
#                                     (JJ old)
#                                     (NN phone)
#                                     (NN number))
#                                   (. .)
#                                   (S
#                                     (PRP i)
#                                     (VP
#                                       (VBD did)
#                                       (RB n't)
#                                       (VP
#                                         (VB give)
#                                         (NP
#                                           (NP
#                                             (NN review)
#                                             (NNS stars))
#                                           (PP
#                                             (IN for)
#                                             (NP
#                                               (NP (NN everything))
#                                               (PP
#                                                 (IN since)
#                                                 (S
#                                                   (NP (PRP i))
#                                                   (VP
#                                                     (VBP have)
#                                                     (NP
#                                                       (NP
#                                                         (DT no)
#                                                         (NN idea))
#                                                       (PP
#                                                         (IN about)
#                                                         (NP
#                                                           (NP
#                                                             (NN
#                                                               battery)
#                                                             (NN life))
#                                                           (CC or)
#                                                           (NP
#                                                             (NN
#                                                               longevity)))))))))))))))))))))))))))))
#     (, ,)
#     (S
#       (ADVP (RB well))
#       (PRP$ its)
#       (VP
#         (VBD worked)
#         (ADVP (JJ fine))
#         (PP (IN for) (NP (CD 3) (NNS days)))))
#     (. .)))
# (TOP
#   (S
#     (NP (DT this) (NN phone))
#     (VP
#       (VP
#         (VP
#           (VBZ has)
#           (VP (VBN been) (ADJP (RB absolutely) (JJ amazing))))
#         (. !)
#         (S
#           (NP (PRP it))
#           (VP
#             (VBD did)
#             (VP
#               (VBN come)
#               (PP
#                 (IN with)
#                 (NP
#                   (NP (DT a) (JJ few) (NNS blemishes/scratches))
#                   (PP (IN on) (NP (DT the) (NNS edges)))))))))
#       (, ,)
#       (CC but)
#       (S
#         (S
#           (NP (PRP they))
#           (VP (VBD were) (VP (VBN painted) (ADVP (IN over)))))
#         (CC and)
#         (S
#           (NP (PRP i))
#           (VP
#             (VBP don)
#             (DT ’)
#             (RB t)
#             (ADVP (RB really))
#             (VP
#               (VB mind)
#               (PP
#                 (IN due)
#                 (IN to)
#                 (NP
#                   (DT the)
#                   (NN fact)
#                   (SBAR
#                     (S
#                       (NP (PRP i))
#                       (VP
#                         (MD will)
#                         (VP
#                           (VB have)
#                           (S
#                             (NP (DT a) (NN case))
#                             (VP (VBG covering) (NP (PRP it)))))))))))))))
#     (. .)
#     (NP
#       (S
#         (NP (PRP i))
#         (VP
#           (VBD was)
#           (ADJP (RB very) (JJ skeptical))
#           (PP (IN at) (ADVP (RB first)))
#           (SBAR
#             (WHADVP (WRB when))
#             (S
#               (S (VP (VBG getting) (NP (DT this) (NN phone))))
#               (SBAR
#                 (IN because)
#                 (S
#                   (NP (DT the) (NN price))
#                   (VP
#                     (VBZ seems)
#                     (S
#                       (VP
#                         (PP (TO to) (ADJP (JJ good)))
#                         (S
#                           (VP (TO to) (VP (VB be) (ADJP (JJ true))))))))))))))
#       (, ,)
#       (CC but)
#       (NP
#         (S
#           (NP
#             (S
#               (NP (PRP i))
#               (VP
#                 (VBP have)
#                 (VP
#                   (VP
#                     (VBN had)
#                     (NP (PRP it))
#                     (NP
#                       (QP (CD two) (RB almost) (CD three))
#                       (JJ full)
#                       (NNS weeks)))
#                   (CC and)
#                   (S
#                     (NP (NN everything))
#                     (VP
#                       (VBZ seems)
#                       (S
#                         (VP
#                           (TO to)
#                           (VP
#                             (VB be)
#                             (VP (VBG working) (RB just) (JJ fine))))))))))
#             (. .)
#             (NP
#               (NP (DT the) (JJ only) (JJ bad) (NN thing))
#               (PP (IN about) (NP (DT this) (NN phone)))))
#           (VP
#             (VBZ is)
#             (SBAR
#               (IN that)
#               (S
#                 (NP (DT the) (JJ maximum) (NN battery) (NN space))
#                 (VP
#                   (VBZ is)
#                   (NP
#                     (CD 76)
#                     (NN %)
#                     (SBAR
#                       (WHNP (WDT which))
#                       (S
#                         (ADVP (RB honestly))
#                         (VP
#                           (VBZ is)
#                           (VP
#                             (VBN expected)
#                             (PP
#                               (IN for)
#                               (NP
#                                 (JJ such)
#                                 (DT a)
#                                 (JJ low)
#                                 (NN cost)))))))))))))
#         (. .)
#         (NP (PRP i))))
#     (VP
#       (MD would)
#       (ADVP
#         (ADVP (RB definitely))
#         (VP (VB buy) (NP (DT this) (NN product)) (ADVP (RB again)))))))
# (TOP
#   (S
#     (S (NP (NNP siri)) (VP (VBZ does) (RB n't) (VP (VB work))))
#     (, ,)
#     (ADJP (RB cosmetically) (JJ great))
#     (PP
#       (PP
#         (IN besides)
#         (NP
#           (NP (DT the) (NN ear) (NN speaker))
#           (VP (VBN broken) (PRT (RP out)))))
#       (. .)
#       (VP (VBZ has) (NP (JJ great) (NN battery) (NN life))))
#     (, ,)
#     (S
#       (NP (PRP i))
#       (VP
#         (VBP am)
#         (PP (IN on) (NP (PRP$ my) (NN phone)))
#         (ADVP (RB constantly))))
#     (CC and)
#     (S
#       (NP (DT the) (NN battery) (NN life))
#       (VP
#         (VP
#           (VP (VBZ lasts) (ADVP (DT all) (NN day) (RB long)))
#           (. .)
#           (S
#             (NP (NN face) (NN recognition))
#             (VP
#               (VBZ works)
#               (NP
#                 (NP (DT the) (NN way))
#                 (SBAR
#                   (S
#                     (NP (PRP it))
#                     (VP
# ...
#               (NP (NN use))
#               (PP (IN to) (NP (DT this) (CD phone11))))))))
#     (: ;)
#     (S
#       (S
#         (S (NP (PRP i)) (VP (VBD had) (NP (DT an) (NN se))))
#         (-RRB- .)
#         (S
#           (S
#             (NP
#               (NP (DT the) (NN reason))
#               (SBAR (S (NP (PRP i)) (VP (VBD updated)))))
#             (VP
#               (VBD was)
#               (SBAR
#                 (S
#                   (NP (PRP$ my) (NN battery))
#                   (VP
#                     (VBD ran)
#                     (ADVP (RB down))
#                     (PP (IN by) (NP (CD 4:00) (NN pm)))
#                     (NP (DT every) (NN day))
#                     (PP
#                       (IN after)
#                       (NP
#                         (DT a)
#                         (JJ full)
#                         (NML (CD 10) (NN hr))
#                         (NN night)
#                         (NN charge))))))))
#           (. .)
#           (S
#             (NP (DT this) (NN phone))
#             (VP
#               (VBZ makes)
#               (NP (PRP it))
#               (PP (IN to) (NP (CD 5:00)))))))
#       (: ;)
#       (S
#         (NP
#           (S
#             (NP (PRP i))
#             (VP
#               (VBD expected)
#               (S
#                 (VP
#                   (TO to)
#                   (VP
#                     (VB hold)
#                     (NP (DT the) (NN charge))
#                     (ADVP (RBR longer)))))))
#           (. .)
#           (NP (DT that)))
#         (VP
#           (VBZ is)
#           (NP (DT a) (NN disappointment))
#           (SBAR
#             (IN because)
#             (S
#               (NP (PRP i))
#               (VP
#                 (VBD thought)
#                 (SBAR
#                   (S
#                     (NP (NN literature))
#                     (VP
#                       (VBD said)
#                       (SBAR
#                         (S
#                           (NP (DT the) (NN battery))
#                           (VP
#                             (VBD was)
#                             (ADJP
#                               (ADJP (JJR better))
#                               (PP (IN than) (NP (CD 9) (NNS hours))))))))))))))))
#     (. .)))
# (TOP
#   (S
#     (NP (PRP we))
#     (VP
#       (VBD had)
#       (S
#         (VP
#           (TO to)
#           (VB purchase)
#           (NP (PRP$ our) (NN daughter))
#           (DT a)
#           (JJ new)
#           (NN phone)))
#       (NP (JJ last) (NN minute))
#       (S
#         (VP
#           (VBG seeing)
#           (SBAR
#             (SBAR
#               (IN as)
#               (S
#                 (NP (PRP hers))
#                 (VP
#                   (VP
#                     (VBD fell)
#                     (PP (IN off) (NP (DT the) (NN counter))))
#                   (CC and)
#                   (VP (VBD broke)))))
#             (, ,)
#             (S
#               (NP (PRP she))
#               (VP
#                 (MD could)
#                 (RB n't)
#                 (VP
#                   (VB use)
#                   (NP (PRP it))
#                   (SBAR
#                     (IN because)
#                     (S
#                       (NP (DT the) (NN touch) (NN screen))
#                       (VP (VBD got) (VP (VBN broke))))))))))))
#     (. .)
#     (ADVP (RB anyway))
#     (, ,)
#     (S
#       (S
#         (S
#           (PP
#             (RB instead)
#             (IN of)
#             (S (VP (VBG getting) (NP (DT the) (JJ same) (NN model)))))
#           (NP (PRP we))
#           (VP
#             (VBD upgraded)
#             (NP (PRP her))
#             (PP
#               (IN to)
#               (NP (DT the) (JJ mint) (NN apple) (NN iphone) (CD 11)))))
#         (, ,)
#         (NP (PRP we))
#         (ADVP (RB just))
#         (VP
#           (VBD received)
#           (NP (PRP it))
#           (ADVP
#             (NP (NN today))
#             (IN so)
#             (S
#               (VP
#                 (MD ca)
#                 (RB n't)
#                 (VP
#                   (VB comment)
#                   (PP
#                     (IN on)
#                     (SBAR
#                       (SBAR
#                         (WHADVP (WRB how))
#                         (S
#                           (NP (PRP it))
#                           (VBZ operates)
#                           (ADJP (RB much))))
#                       (ADVP (RB yet))))))))))
#       (, ,)
#       (CC but)
#       (S
#         (NP (PRP i))
#         (VP
#           (VBP do)
#           (VP
#             (VB want)
#             (S
#               (VP
#                 (TO to)
#                 (VP
#                   (VB say)
#                   (SBAR
#                     (IN that)
#                     (S
#                       (NP (PRP she))
#                       (VP
#                         (VBZ 's)
#                         (PP
#                           (RB absolutely)
#                           (IN in)
#                           (NP
#                             (NP (NN love))
#                             (PP
#                               (IN with)
#                               (NP
#                                 (NP
#                                   (NP
#                                     (NP
#                                       (NP (PRP it))
#                                       (CC and)
#                                       (NP (DT the) (NN color)))
#                                     (. !)
#                                     (NP (DT the) (NN seller)))
#                                   (VP
#                                     (VBD was)
#                                     (ADJP
#                                       (RB very)
#                                       (JJ swift)
#                                       (PP
#                                         (IN at)
#                                         (S
#                                           (VP
#                                             (VBG replying)
#                                             (PP
#                                               (IN to)
#                                               (NP
#                                                 (NP
#                                                   (PRP$ my)
#                                                   (NNS questions)
#                                                   (CC and)
#                                                   (NNS inquiries))
#                                                 (PP
#                                                   (IN on)
#                                                   (NP (PRP it)))))))))))
#                                 (, ,)
#                                 (S
#                                   (NP (PRP they))
#                                   (VP
#                                     (VP
#                                       (VBD went)
#                                       (ADVP
#                                         (IN above)
#                                         (CC and)
#                                         (RB beyond)))
#                                     (. !)
#                                     (. !)
#                                     (. !)
#                                     (ADVP (RB also))
#                                     (, ,)
#                                     (S
#                                       (NP (PRP they))
#                                       (VP
#                                         (VP
#                                           (VBD shipped)
#                                           (NP (PRP it))
#                                           (ADVP
#                                             (RB right)
#                                             (PRT (RP out)))
#                                           (, ,))
#                                         (CC and)
#                                         (S
#                                           (NP (PRP we))
#                                           (VP
#                                             (VBD got)
#                                             (NP
#                                               (NP (PRP it))
#                                               (NP
#                                                 (ADVP
#                                                   (NP
#                                                     (CD two)
#                                                     (NNS days))
#                                                   (RBR sooner))
#                                                 (IN then)
#                                                 (S
#                                                   (NP (NNP amazon))
#                                                   (VP
#                                                     (VBD said)
#                                                     (SBAR
#                                                       (S
#                                                         (NP (PRP we))
#                                                         (VP
#                                                           (MD would)
#                                                           (VP
#                                                             (VB
#                                                               receive)
#                                                             (NP
#                                                               (PRP
#                                                                 it))))))))))))))))))))))))))))))
#     (. !)
#     (NP
#       (NP
#         (NP
#           (NP (CD 5) (NNS stars))
#           (PP (IN to) (NP (DT the) (NN seller))))
#         (. !))
#       (. !))
#     (. !)))
# (TOP
#   (S
#     (S
#       (NP (PRP i))
#       (VP
#         (VBD was)
#         (ADJP
#           (RB very)
#           (JJ hesitant)
#           (PP
#             (IN on)
#             (S (VP (VBG making) (NP (DT this) (NN purchase))))))
#         (PP
#           (IN after)
#           (S (VP (VBG reading) (NP (DT the) (NNS reviews)))))))
#     (. .)
#     (ADVP (RB however))
#     (, ,)
#     (S
#       (NP (PRP i))
#       (VP
#         (VP
#           (VP (VBD bought) (NP (DT the) (NN phone)))
#           (CC and)
#           (VP
#             (VBD received)
#             (NP (PRP it))
#             (PP (IN in) (NP (JJ great) (NN condition)))))
#         (. .)
#         (S
#           (NP (DT the) (NN battery) (NN health))
#           (VP (VBZ is) (ADJP (JJ good))))))
#     (CC and)
#     (S
#       (S
#         (NP
#           (S
#             (NP
#               (NP (DT the) (NN quality))
#               (PP (IN of) (NP (DT the) (NN camera))))
#             (VP (VBZ is) (ADJP (JJ good))))
#           (. .)
#           (NP (PRP i)))
#         (VP (VBD bought) (NP (PRP it)) (NP (JJ last) (NN month))))
#       (CC and)
#       (S
#         (NP (DT the) (NN phone))
#         (VP (VBZ is) (VP (VBG functioning) (ADVP (RB well))))))
#     (. .)))
# (TOP
#   (S
#     (S (NP (NN shipping)) (VP (VBD was) (ADJP (JJ quick))))
#     (CC and)
#     (S
#       (S
#         (NP (JJ excellent) (NN shape))
#         (VP (VBD described) (NP (PRP it)) (ADVP (RB perfectly))))
#       (. .)
#       (S
#         (NP (PRP$ my) (NN wife))
#         (VP
#           (VBD bought)
#           (NP (DT an) (NN iphone) (CD 12))
#           (PP
#             (PP
#               (ADVP (RB shortly))
#               (IN after)
#               (NP (PRP$ my) (NN purchase)))
#             (SBAR
#               (WHNP (WDT that))
#               (S
#                 (VP
#                   (VBD was)
#                   (ADVP (RB also))
#                   (VP
#                     (VBN supposed)
#                     (S
#                       (VP
#                         (TO to)
#                         (VP (VB be) (NP (JJ excellent) (NN shape)))))))))))))
#     (, ,)
#     (CC but)
#     (S
#       (NP (PRP it))
#       (VP
#         (VBD had)
#         (NP
#           (NP (ADJP (JJR more) (JJ noticeable)) (NNS defects))
#           (PP (IN than) (NP (PRP$ my) (JJ refurbished) (CD 11))))))
#     (IN so)
#     (S
#       (NP
#         (S
#           (NP (PRP it))
#           (VP
#             (VBD made)
#             (S
#               (NP (PRP me))
#               (ADJP
#                 (RB really)
#                 (JJ happy)
#                 (PP (IN about) (NP (PRP$ my) (NN purchase)))))))
#         (. .)
#         (NP (PRP i)))
#       (VP
#         (VBP think)
#         (SBAR
#           (S
#             (SBAR
#               (S
#                 (NP (EX there))
#                 (VP
#                   (VBZ is)
#                   (NP
#                     (NP (DT some) (NN variation))
#                     (PP
#                       (IN in)
#                       (SBAR
#                         (WHNP (WP what))
#                         (S
#                           (NP (DT some) (NNS people))
#                           (VP (VBP call) (S (ADJP (JJ excellent)))))))))))
#             (, ,)
#             (IN so)
#             (S
#               (NP (PRP you))
#               (ADVP (RB kind) (RB of))
#               (VP
#                 (VB hope)
#                 (S
#                   (VP
#                     (TO to)
#                     (VP
#                       (VP
#                         (VP
#                           (VP (VB get) (ADJP (JJ lucky)))
#                           (CC and)
#                           (VP
#                             (VB have)
#                             (NP
#                               (NP (NN one))
#                               (SBAR
#                                 (WHNP (WDT that))
#                                 (S
#                                   (NP (NN someone))
#                                   (VP
#                                     (VBD took)
#                                     (NP
#                                       (RB extra)
#                                       (JJ good)
#                                       (NN care))
#                                     (PP (IN of))))))))
#                         (. .)
#                         (NP
#                           (NP (NN battery) (NN life))
#                           (PP (IN on) (NP (PRP$ my) (CD 11)))))
#                       (VP
#                         (VP (VBZ is) (ADJP (JJ amazing)))
#                         (. !)
#                         (SBAR
#                           (ADVP (RB even))
#                           (IN though)
#                           (S
#                             (S
#                               (NP (PRP it))
#                               (VP
#                                 (VBZ says)
#                                 (NP (NML (CD 86) (NN %)) (NN life))))
#                             (, ,)
#                             (NP (PRP i))
#                             (VP
#                               (VBP have)
#                               (VP
#                                 (VBN had)
#                                 (S
#                                   (NP (PRP it))
#                                   (VP
#                                     (VB go)
#                                     (NP
#                                       (NP
#                                         (CD 3)
#                                         (JJ full)
#                                         (NNS days))
#                                       (PP
#                                         (IN between)
#                                         (NP (NNS charges))))
#                                     (PP
#                                       (IN on)
#                                       (NP
#                                         (NP
#                                           (NP (NN occasion))
#                                           (WRB when)
#                                           (PRP i))
#                                         (. have)
#                                         (RB n't)
#                                         (VP
#                                           (VBN used)
#                                           (NP (PRP it))
#                                           (PP
#                                             (IN for)
#                                             (S
#                                               (VP
#                                                 (VBG watching)
#                                                 (NP (NNS things))))))))))))))))))))))))
#     (. .)))

# %%
import spacy.cli
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy
#specifying options for the parse tree
nlp = spacy.load('en')
spacy.blank: nlp = spacy.blank("en")
options = {'compact': True, 'font': 'Arial black', 'distance': 100}
for sentence in df['Lower Case']:
  doc = nlp(sentence)
  displacy.render(doc, style = 'dep', options=options, jupyter=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-50-e26f156b8025> in <module>
#       2 from spacy import displacy
#       3 #specifying options for the parse tree
# ----> 4 nlp = spacy.load('en')
#       5 spacy.blank: nlp = spacy.blank("en")
#       6 options = {'compact': True, 'font': 'Arial black', 'distance': 100}
#
# /usr/local/lib/python3.8/dist-packages/spacy/__init__.py in load(name, vocab, disable, enable, exclude, config)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#
# /usr/local/lib/python3.8/dist-packages/spacy/util.py in load_model(name, vocab, disable, enable, exclude, config)
#     436         return load_model_from_path(name, **kwargs)  # type: ignore[arg-type]
#     437     if name in OLD_MODEL_SHORTCUTS:
# --> 438         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
#     439     raise IOError(Errors.E050.format(name=name))
#     440
#
# OSError: [E941] Can't find model 'en'. It looks like you're trying to load a model from a shortcut, which is obsolete as of spaCy v3.0. To load the model, use its full name instead:
#
# nlp = spacy.load("en_core_web_sm")
#
# For more details on the available models, see the models directory: https://spacy.io/models. If you want to create a blank model, use spacy.blank: nlp = spacy.blank("en")

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()
#categorising words into pre-defined labels
for sentence in df['Lower Case']:
  doc = nlp(sentence)
  for X in doc.ents:
    if X.text and X.label_:
      print([(X.text, X.label_)])
# Out:
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('two', 'CARDINAL')]
# [('almost three full weeks', 'DATE')]
# [('76%', 'PERCENT')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('two', 'CARDINAL')]
# [('almost three full weeks', 'DATE')]
# [('76%', 'PERCENT')]
# [('siri', 'GPE')]
# [('all day', 'DATE')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('two', 'CARDINAL')]
# [('almost three full weeks', 'DATE')]
# [('76%', 'PERCENT')]
# [('siri', 'GPE')]
# [('all day', 'DATE')]
# [('5 days', 'DATE')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('two', 'CARDINAL')]
# [('almost three full weeks', 'DATE')]
# [('76%', 'PERCENT')]
# [('siri', 'GPE')]
# [('all day', 'DATE')]
# [('5 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('4', 'CARDINAL')]
# [('86%', 'PERCENT')]
# [('at least 89%', 'PERCENT')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('two', 'CARDINAL')]
# [('almost three full weeks', 'DATE')]
# [('76%', 'PERCENT')]
# [('siri', 'GPE')]
# [('all day', 'DATE')]
# [('5 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('4', 'CARDINAL')]
# [('86%', 'PERCENT')]
# [('at least 89%', 'PERCENT')]
# [('phone11', 'ORG')]
# [('4:00 pm', 'TIME')]
# [('5:00', 'TIME')]
# [('9 hours', 'TIME')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('two', 'CARDINAL')]
# [('almost three full weeks', 'DATE')]
# [('76%', 'PERCENT')]
# [('siri', 'GPE')]
# [('all day', 'DATE')]
# [('5 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('4', 'CARDINAL')]
# [('86%', 'PERCENT')]
# [('at least 89%', 'PERCENT')]
# [('phone11', 'ORG')]
# [('4:00 pm', 'TIME')]
# [('5:00', 'TIME')]
# [('9 hours', 'TIME')]
# [('last minute', 'TIME')]
# [('11', 'CARDINAL')]
# [('today', 'DATE')]
# [('two days', 'DATE')]
# [('5', 'CARDINAL')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('two', 'CARDINAL')]
# [('almost three full weeks', 'DATE')]
# [('76%', 'PERCENT')]
# [('siri', 'GPE')]
# [('all day', 'DATE')]
# [('5 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('4', 'CARDINAL')]
# [('86%', 'PERCENT')]
# [('at least 89%', 'PERCENT')]
# [('phone11', 'ORG')]
# [('4:00 pm', 'TIME')]
# [('5:00', 'TIME')]
# [('9 hours', 'TIME')]
# [('last minute', 'TIME')]
# [('11', 'CARDINAL')]
# [('today', 'DATE')]
# [('two days', 'DATE')]
# [('5', 'CARDINAL')]
# [('last month', 'DATE')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('two', 'CARDINAL')]
# [('almost three full weeks', 'DATE')]
# [('76%', 'PERCENT')]
# [('siri', 'GPE')]
# [('all day', 'DATE')]
# [('5 days', 'DATE')]
# [('first', 'ORDINAL')]
# [('4', 'CARDINAL')]
# [('86%', 'PERCENT')]
# [('at least 89%', 'PERCENT')]
# [('phone11', 'ORG')]
# [('4:00 pm', 'TIME')]
# [('5:00', 'TIME')]
# [('9 hours', 'TIME')]
# [('last minute', 'TIME')]
# [('11', 'CARDINAL')]
# [('today', 'DATE')]
# [('two days', 'DATE')]
# [('5', 'CARDINAL')]
# [('last month', 'DATE')]
# [('12', 'CARDINAL')]
# [('11', 'CARDINAL')]
# [('11', 'CARDINAL')]
# [('86%', 'PERCENT')]
# [('3 full days', 'DATE')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]
# [('kinda', 'PERSON')]
# [('faceid and/or', 'PERSON')]
# [('fine.i', 'PERSON')]
# [('overnight', 'TIME')]
# [('100%', 'PERCENT')]
# [('10-hour', 'TIME')]
# [('workday', 'DATE')]
# [('85%', 'PERCENT')]
# [('3 days', 'DATE')]

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %%
Constituency parsing tree:
